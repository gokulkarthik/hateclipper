# %%
import os
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer

info_fp = '../data/hateful_memes/info.csv'
fine_grained_data_dir = '../data/hateful_memes_finegrained'

# %% [markdown]
# # EDA

# %%
split = 'train'
fp = f'{fine_grained_data_dir}/{split}.json'
fine_grained_df = pd.read_json(fp, lines=True)
fine_grained_df.head()
# Out:
#       id set_name            img  \
# 0  42953    train  img/42953.png
# 1  23058    train  img/23058.png
# 2  13894    train  img/13894.png
# 3  37408    train  img/37408.png
# 4  82403    train  img/82403.png
#
#                                                 text      gold_hate  \
# 0   its their character not their color that matters  [not_hateful]
# 1  don't be afraid to love again everyone is not ...  [not_hateful]
# 2                           putting bows on your pet  [not_hateful]
# 3  i love everything and everybody! except for sq...  [not_hateful]
# 4  everybody loves chocolate chip cookies, even h...  [not_hateful]
#
#       gold_pc     gold_attack    pc attack
# 0  [pc_empty]  [attack_empty]  None   None
# 1  [pc_empty]  [attack_empty]  None   None
# 2  [pc_empty]  [attack_empty]  None   None
# 3  [pc_empty]  [attack_empty]  None   None
# 4  [pc_empty]  [attack_empty]  None   None

# %%
fine_grained_df.tail()
# Out:
#          id set_name            img  \
# 8495  10423    train  img/10423.png
# 8496  98203    train  img/98203.png
# 8497  36947    train  img/36947.png
# 8498  16492    train  img/16492.png
# 8499  15937    train  img/15937.png
#
#                                                    text  gold_hate  \
# 8495                  nobody wants to hang auschwitz me  [hateful]
# 8496  when god grants you a child after 20 years of ...  [hateful]
# 8497  gays on social media: equality! body positivit...  [hateful]
# 8498  having a bad day? you could be a siamese twin ...  [hateful]
# 8499  i hate muslims too they take their religion to...  [hateful]
#
#                 gold_pc              gold_attack  \
# 8495         [religion]                [mocking]
# 8496      [nationality]           [dehumanizing]
# 8497              [sex]              [exclusion]
# 8498  [sex, disability]            [inferiority]
# 8499         [religion]  [inferiority, contempt]
#
#                                                      pc  \
# 8495               [[religion], [religion], [religion]]
# 8496         [[nationality], [nationality], [religion]]
# 8497                              [[sex], [sex], [sex]]
# 8498  [[sex, disability], [sex, disability], [sex, d...
# 8499               [[religion], [religion], [religion]]
#
#                                                  attack
# 8495                  [[mocking], [mocking], [mocking]]
# 8496          [[dehumanizing], [inciting_violence], []]
# 8497            [[exclusion], [exclusion], [exclusion]]
# 8498                 [[], [inferiority], [inferiority]]
# 8499  [[inferiority, contempt], [inferiority, contem...

# %%
(fine_grained_df['gold_pc'].apply(lambda x: len(x)) > 1).sum()
# Out:
# 389

# %%
(fine_grained_df['gold_attack'].apply(lambda x: len(x)) > 1).sum()
# Out:
# 327

# %%
mlb = MultiLabelBinarizer()
transformed = mlb.fit_transform(fine_grained_df['gold_attack'])
print(transformed.shape)
print(mlb.classes_)
# Out:
# (8500, 8)
# ['attack_empty' 'contempt' 'dehumanizing' 'exclusion' 'inciting_violence'
#  'inferiority' 'mocking' 'slurs']

# %%
def find_unique_labels(lists, empty_replacement):

     if isinstance(lists, list):
          return list({item for lst in lists for item in lst})
     return [empty_replacement]

# %%
(fine_grained_df['pc'].apply(find_unique_labels, empty_replacement='pc_empty').apply(lambda x: len(x)) > 1).sum()
# Out:
# 1077

# %%
(fine_grained_df['attack'].apply(find_unique_labels, empty_replacement='attack_empty').apply(lambda x: len(x)) > 1).sum()
# Out:
# 1476

# %% [markdown]
# # Transform data

# %%
def find_unique_labels(lists, empty_replacement):

     if isinstance(lists, list):
          return list({item for lst in lists for item in lst})
     return [empty_replacement]

# %%
splits = ['train', 'dev_seen', 'dev_unseen']
fine_grained_dfs = []
for split in splits:
    fp = f'{fine_grained_data_dir}/{split}.json'
    fine_grained_df = pd.read_json(fp, lines=True)
    fine_grained_dfs.append(fine_grained_df)
fine_grained_df = pd.concat(fine_grained_dfs)

mlb_pc, mlb_attack = MultiLabelBinarizer(), MultiLabelBinarizer()
mlb_pc.fit(fine_grained_df['gold_pc'])
mlb_attack.fit(fine_grained_df['gold_attack'])
# Out:
# MultiLabelBinarizer()

# %%
splits = ['train', 'dev_seen', 'dev_unseen']
fine_grained_dfs = []
for split in splits:
    fp = f'{fine_grained_data_dir}/{split}.json'
    fine_grained_df = pd.read_json(fp, lines=True)
    # transform 'pc' like 'gold_pc'
    fine_grained_df['pc'] = fine_grained_df['pc'].apply(find_unique_labels, empty_replacement='pc_empty')
    # transform 'attack' like 'gold_attack'
    fine_grained_df['attack'] = fine_grained_df['attack'].apply(find_unique_labels, empty_replacement='attack_empty')
    # binarize 'gold_pc' and 'gold_attack'
    new_cols = [x+'_gold_pc' for x in mlb_pc.classes_]
    fine_grained_df[new_cols] = mlb_pc.transform(fine_grained_df['gold_pc'])
    new_cols = [x+'_gold_attack' for x in mlb_attack.classes_]
    fine_grained_df[new_cols] = mlb_attack.transform(fine_grained_df['gold_attack'])
    # binarize 'pc' and 'attack'
    new_cols = [x+'_pc' for x in mlb_pc.classes_]
    fine_grained_df[new_cols] = mlb_pc.transform(fine_grained_df['pc'])
    new_cols = [x+'_attack' for x in mlb_attack.classes_]
    fine_grained_df[new_cols] = mlb_attack.transform(fine_grained_df['attack'])

    fine_grained_dfs.append(fine_grained_df)

fine_grained_df = pd.concat(fine_grained_dfs)
print(fine_grained_df.shape)
fine_grained_df.head()
# Out:
# (9540, 37)
# /home/gokul_kumar/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:860: UserWarning: unknown class(es) ['class'] will be ignored
#   warnings.warn('unknown class(es) {0} will be ignored'
#       id set_name            img  \
# 0  42953    train  img/42953.png
# 1  23058    train  img/23058.png
# 2  13894    train  img/13894.png
# 3  37408    train  img/37408.png
# 4  82403    train  img/82403.png
#
#                                                 text      gold_hate  \
# 0   its their character not their color that matters  [not_hateful]
# 1  don't be afraid to love again everyone is not ...  [not_hateful]
# 2                           putting bows on your pet  [not_hateful]
# 3  i love everything and everybody! except for sq...  [not_hateful]
# 4  everybody loves chocolate chip cookies, even h...  [not_hateful]
#
#       gold_pc     gold_attack          pc          attack  disability_gold_pc  \
# 0  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]                   0
# 1  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]                   0
# 2  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]                   0
# 3  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]                   0
# 4  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]                   0
#
#    ...  religion_pc  sex_pc  attack_empty_attack  contempt_attack  \
# 0  ...            0       0                    1                0
# 1  ...            0       0                    1                0
# 2  ...            0       0                    1                0
# 3  ...            0       0                    1                0
# 4  ...            0       0                    1                0
#
#    dehumanizing_attack  exclusion_attack  inciting_violence_attack  \
# 0                    0                 0                         0
# 1                    0                 0                         0
# 2                    0                 0                         0
# 3                    0                 0                         0
# 4                    0                 0                         0
#
#    inferiority_attack  mocking_attack  slurs_attack
# 0                   0               0             0
# 1                   0               0             0
# 2                   0               0             0
# 3                   0               0             0
# 4                   0               0             0
#
# [5 rows x 37 columns]

# %%
(fine_grained_df['gold_pc'] == fine_grained_df['pc']).mean()
# Out:
# 0.8805031446540881

# %%
(fine_grained_df['gold_attack'] == fine_grained_df['attack']).mean()
# Out:
# 0.8276729559748428

# %%
cols_to_remove = ['img', 'text', 'gold_hate']
fine_grained_df = fine_grained_df.drop(columns=cols_to_remove)
fine_grained_df = fine_grained_df.rename(columns={'set_name':'split'})
print(fine_grained_df.shape)
fine_grained_df.head()
# Out:
# (9540, 34)
#       id  split     gold_pc     gold_attack          pc          attack  \
# 0  42953  train  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]
# 1  23058  train  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]
# 2  13894  train  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]
# 3  37408  train  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]
# 4  82403  train  [pc_empty]  [attack_empty]  [pc_empty]  [attack_empty]
#
#    disability_gold_pc  nationality_gold_pc  pc_empty_gold_pc  race_gold_pc  \
# 0                   0                    0                 1             0
# 1                   0                    0                 1             0
# 2                   0                    0                 1             0
# 3                   0                    0                 1             0
# 4                   0                    0                 1             0
#
#    ...  religion_pc  sex_pc  attack_empty_attack  contempt_attack  \
# 0  ...            0       0                    1                0
# 1  ...            0       0                    1                0
# 2  ...            0       0                    1                0
# 3  ...            0       0                    1                0
# 4  ...            0       0                    1                0
#
#    dehumanizing_attack  exclusion_attack  inciting_violence_attack  \
# 0                    0                 0                         0
# 1                    0                 0                         0
# 2                    0                 0                         0
# 3                    0                 0                         0
# 4                    0                 0                         0
#
#    inferiority_attack  mocking_attack  slurs_attack
# 0                   0               0             0
# 1                   0               0             0
# 2                   0               0             0
# 3                   0               0             0
# 4                   0               0             0
#
# [5 rows x 34 columns]

# %%
fine_grained_df.columns
# Out:
# Index(['id', 'split', 'gold_pc', 'gold_attack', 'pc', 'attack',
#        'disability_gold_pc', 'nationality_gold_pc', 'pc_empty_gold_pc',
#        'race_gold_pc', 'religion_gold_pc', 'sex_gold_pc',
#        'attack_empty_gold_attack', 'contempt_gold_attack',
#        'dehumanizing_gold_attack', 'exclusion_gold_attack',
#        'inciting_violence_gold_attack', 'inferiority_gold_attack',
#        'mocking_gold_attack', 'slurs_gold_attack', 'disability_pc',
#        'nationality_pc', 'pc_empty_pc', 'race_pc', 'religion_pc', 'sex_pc',
#        'attack_empty_attack', 'contempt_attack', 'dehumanizing_attack',
#        'exclusion_attack', 'inciting_violence_attack', 'inferiority_attack',
#        'mocking_attack', 'slurs_attack'],
#       dtype='object')

# %%
info_df = pd.read_csv(info_fp)
print(info_df.shape)
info_df.head()
# Out:
# (10000, 8)
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text  split  text_idx  \
# 0   its their character not their color that matters  train         0
# 1  don't be afraid to love again everyone is not ...  train         1
# 2                           putting bows on your pet  train         2
# 3  i love everything and everybody! except for sq...  train         3
# 4  everybody loves chocolate chip cookies, even h...  train         4
#
#    pseudo_text_idx  pseudo_img_idx
# 0             4901               0
# 1             3620            3486
# 2                0            3956
# 3             4451            4313
# 4             5609               1

# %%
# merge fine_grained_df with info_df
info_df = pd.merge(info_df, fine_grained_df, on=['id', 'split'], how='left')
print(info_df.shape)
info_df.tail()
# Out:
# (10000, 40)
#          id            img  label  \
# 9995   3869  img/03869.png      0
# 9996  23817  img/23817.png      0
# 9997  56280  img/56280.png      0
# 9998  29384  img/29384.png      0
# 9999  34127  img/34127.png      0
#
#                                                    text      split  text_idx  \
# 9995    a mother's love for the child is a divine thing  test_seen      8041
# 9996                                        sea monkeys  test_seen      1103
# 9997               little miss muffet sat on her tuffet  test_seen      8042
# 9998                                   they're in a row  test_seen      8043
# 9999  that feeling when you win a fifa game after be...  test_seen      8044
#
#       pseudo_text_idx  pseudo_img_idx gold_pc gold_attack  ... religion_pc  \
# 9995             4783            4628     NaN         NaN  ...         NaN
# 9996              367            6246     NaN         NaN  ...         NaN
# 9997             2518            2395     NaN         NaN  ...         NaN
# 9998             6811            1609     NaN         NaN  ...         NaN
# 9999             2908            1632     NaN         NaN  ...         NaN
#
#      sex_pc  attack_empty_attack  contempt_attack  dehumanizing_attack  \
# 9995    NaN                  NaN              NaN                  NaN
# 9996    NaN                  NaN              NaN                  NaN
# 9997    NaN                  NaN              NaN                  NaN
# 9998    NaN                  NaN              NaN                  NaN
# 9999    NaN                  NaN              NaN                  NaN
#
#       exclusion_attack  inciting_violence_attack  inferiority_attack  \
# 9995               NaN                       NaN                 NaN
# 9996               NaN                       NaN                 NaN
# 9997               NaN                       NaN                 NaN
# 9998               NaN                       NaN                 NaN
# 9999               NaN                       NaN                 NaN
#
#       mocking_attack  slurs_attack
# 9995             NaN           NaN
# 9996             NaN           NaN
# 9997             NaN           NaN
# 9998             NaN           NaN
# 9999             NaN           NaN
#
# [5 rows x 40 columns]

# %%
float_cols = info_df.select_dtypes(float).columns
info_df[float_cols] = info_df.select_dtypes(float).astype('Int64')
info_df.head()
# Out:
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text  split  text_idx  \
# 0   its their character not their color that matters  train         0
# 1  don't be afraid to love again everyone is not ...  train         1
# 2                           putting bows on your pet  train         2
# 3  i love everything and everybody! except for sq...  train         3
# 4  everybody loves chocolate chip cookies, even h...  train         4
#
#    pseudo_text_idx  pseudo_img_idx     gold_pc     gold_attack  ...  \
# 0             4901               0  [pc_empty]  [attack_empty]  ...
# 1             3620            3486  [pc_empty]  [attack_empty]  ...
# 2                0            3956  [pc_empty]  [attack_empty]  ...
# 3             4451            4313  [pc_empty]  [attack_empty]  ...
# 4             5609               1  [pc_empty]  [attack_empty]  ...
#
#   religion_pc sex_pc  attack_empty_attack  contempt_attack  \
# 0           0      0                    1                0
# 1           0      0                    1                0
# 2           0      0                    1                0
# 3           0      0                    1                0
# 4           0      0                    1                0
#
#    dehumanizing_attack  exclusion_attack  inciting_violence_attack  \
# 0                    0                 0                         0
# 1                    0                 0                         0
# 2                    0                 0                         0
# 3                    0                 0                         0
# 4                    0                 0                         0
#
#    inferiority_attack  mocking_attack  slurs_attack
# 0                   0               0             0
# 1                   0               0             0
# 2                   0               0             0
# 3                   0               0             0
# 4                   0               0             0
#
# [5 rows x 40 columns]

# %%
info_df['split'].value_counts()
# Out:
# train        8500
# test_seen    1000
# dev_seen      500
# Name: split, dtype: int64

# %%
info_df.describe()
# Out:
#                  id         label      text_idx  pseudo_text_idx  \
# count  10000.000000  10000.000000  10000.000000     10000.000000
# mean   49934.687100      0.375600   3808.343200      2996.132300
# std    28537.752855      0.484302   2370.330576      2297.623341
# min     1235.000000      0.000000      0.000000         0.000000
# 25%    25728.000000      0.000000   1685.750000       920.000000
# 50%    49739.000000      0.000000   3681.500000      2498.500000
# 75%    74387.000000      1.000000   5843.250000      4998.250000
# max    98764.000000      1.000000   8044.000000      7498.000000
#
#        pseudo_img_idx  disability_gold_pc  nationality_gold_pc  \
# count     10000.00000         9000.000000          9000.000000
# mean       2878.39480            0.030778             0.039000
# std        2267.02814            0.172725             0.193606
# min           0.00000            0.000000             0.000000
# 25%         830.00000            0.000000             0.000000
# 50%        2351.50000            0.000000             0.000000
# 75%        4851.25000            0.000000             0.000000
# max        7351.00000            1.000000             1.000000
#
#        pc_empty_gold_pc  race_gold_pc  religion_gold_pc  ...  religion_pc  \
# count       9000.000000   9000.000000       9000.000000  ...  9000.000000
# mean           0.638778      0.120667          0.130333  ...     0.139333
# std            0.480381      0.325758          0.336689  ...     0.346313
# min            0.000000      0.000000          0.000000  ...     0.000000
# 25%            0.000000      0.000000          0.000000  ...     0.000000
# 50%            1.000000      0.000000          0.000000  ...     0.000000
# 75%            1.000000      0.000000          0.000000  ...     0.000000
# max            1.000000      1.000000          1.000000  ...     1.000000
#
#             sex_pc  attack_empty_attack  contempt_attack  dehumanizing_attack  \
# count  9000.000000          9000.000000      9000.000000          9000.000000
# mean      0.113333             0.638556         0.058778             0.190667
# std       0.317017             0.480446         0.235221             0.392849
# min       0.000000             0.000000         0.000000             0.000000
# 25%       0.000000             0.000000         0.000000             0.000000
# 50%       0.000000             1.000000         0.000000             0.000000
# 75%       0.000000             1.000000         0.000000             0.000000
# max       1.000000             1.000000         1.000000             1.000000
#
#        exclusion_attack  inciting_violence_attack  inferiority_attack  \
# count       9000.000000               9000.000000         9000.000000
# mean           0.022778                  0.079556            0.136889
# std            0.149203                  0.270619            0.343749
# min            0.000000                  0.000000            0.000000
# 25%            0.000000                  0.000000            0.000000
# 50%            0.000000                  0.000000            0.000000
# 75%            0.000000                  0.000000            0.000000
# max            1.000000                  1.000000            1.000000
#
#        mocking_attack  slurs_attack
# count     9000.000000   9000.000000
# mean         0.055444      0.031222
# std          0.228858      0.173927
# min          0.000000      0.000000
# 25%          0.000000      0.000000
# 50%          0.000000      0.000000
# 75%          0.000000      0.000000
# max          1.000000      1.000000
#
# [8 rows x 33 columns]

# %%
info_df.to_csv(info_fp.replace('info', 'info_fine_grained'), index=False)

# %%
pc_columns = [col for col in info_df.columns if col.endswith('_pc') and not 'gold' in col]
attack_columns = [col for col in info_df.columns if col.endswith('_attack') and not 'gold' in col]
fine_grained_labels = pc_columns + attack_columns
print(fine_grained_labels)
# Out:
# ['disability_pc', 'nationality_pc', 'pc_empty_pc', 'race_pc', 'religion_pc', 'sex_pc', 'attack_empty_attack', 'contempt_attack', 'dehumanizing_attack', 'exclusion_attack', 'inciting_violence_attack', 'inferiority_attack', 'mocking_attack', 'slurs_attack']

# %%
with open('fine_grained_labels.txt', 'w') as file:
    file.writelines([line+'\n' for line in fine_grained_labels])
