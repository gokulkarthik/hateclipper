# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from tqdm.auto import tqdm

data_dir = '../data/hateful_memes'
img_dir = os.path.join(data_dir, 'img')

# %%
print(len(os.listdir(img_dir)))
# Out:
# 12141

# %%
splits = ['train', 'dev_seen', 'test_seen']
df = []
for split in splits:
    file_path = os.path.join(data_dir, f'{split}.jsonl')
    split_df = pd.read_json(file_path, lines=True)
    split_df['split'] = split
    df.append(split_df)

df = pd.concat(df, axis=0, ignore_index=True)
df['id'] = df['img'].str.split('/').str[1].str.split('.').str[0]
df.index = df['id']
df.index.name = None
print(df.shape)
df.head()
# Out:
# (10000, 5)
#           id            img  label  \
# 42953  42953  img/42953.png      0
# 23058  23058  img/23058.png      0
# 13894  13894  img/13894.png      0
# 37408  37408  img/37408.png      0
# 82403  82403  img/82403.png      0
#
#                                                     text  split
# 42953   its their character not their color that matters  train
# 23058  don't be afraid to love again everyone is not ...  train
# 13894                           putting bows on your pet  train
# 37408  i love everything and everybody! except for sq...  train
# 82403  everybody loves chocolate chip cookies, even h...  train

# %%
df['split'].value_counts()
# Out:
# train        8500
# test_seen    1000
# dev_seen      500
# Name: split, dtype: int64

# %%
#df = df[df['split']=='train']

# %%
df['label'].value_counts(normalize=False)
# Out:
# 0    6244
# 1    3756
# Name: label, dtype: int64

# %%
df['text'].nunique()
# Out:
# 8045

# %% [markdown]
# # Match Images based on Text

# %%
idx_to_text = {idx:text for idx, text in enumerate(df['text'].unique())}
text_to_idx = {v:k for k, v in idx_to_text.items()}

# %%
df['text_idx'] = df['text'].map(text_to_idx)
df.head()
# Out:
#           id            img  label  \
# 42953  42953  img/42953.png      0
# 23058  23058  img/23058.png      0
# 13894  13894  img/13894.png      0
# 37408  37408  img/37408.png      0
# 82403  82403  img/82403.png      0
#
#                                                     text  split  text_idx
# 42953   its their character not their color that matters  train         0
# 23058  don't be afraid to love again everyone is not ...  train         1
# 13894                           putting bows on your pet  train         2
# 37408  i love everything and everybody! except for sq...  train         3
# 82403  everybody loves chocolate chip cookies, even h...  train         4

# %%
df['text_idx'].value_counts()[:100].plot.bar(figsize=(30,5))
# Out:
# <AxesSubplot:>

# %%
df['text_idx'].value_counts().value_counts()
# Out:
# 1     6548
# 2     1301
# 3      114
# 4       42
# 6       12
# 5       11
# 10       5
# 8        3
# 15       2
# 7        2
# 44       1
# 17       1
# 13       1
# 12       1
# 9        1
# Name: text_idx, dtype: int64

# %%
# {text_id: [meme_idx_1, ...], ...}
text_idx_to_memes = df.groupby('text_idx')['id'].apply(list).to_dict()
text_idx_to_memes = {k:v for k, v in text_idx_to_memes.items() if len(v) > 1}
print(len(text_idx_to_memes))
# Out:
# 1497

# %%
text_idx_to_label_to_memes = {}
for text_idx, memes in text_idx_to_memes.items():
    text_idx_to_label_to_memes[text_idx] = {}
    text_idx_to_label_to_memes[text_idx]['non-hateful'] = []
    text_idx_to_label_to_memes[text_idx]['hateful'] = []

    hateful_added, non_hateful_added = False, False
    for meme_idx in memes:
        if df.loc[meme_idx]['label'] == 0:
            text_idx_to_label_to_memes[text_idx]['non-hateful'].append(meme_idx)
            non_hateful_added = True
        else:
            text_idx_to_label_to_memes[text_idx]['hateful'].append(meme_idx)
            hateful_added = True

    if not hateful_added or not non_hateful_added:
        del text_idx_to_label_to_memes[text_idx]

    # if len(text_idx_to_label_to_memes[text_idx]['non-hateful']) == 0:
    #     del text_idx_to_label_to_memes[text_idx]['non-hateful']
    # if len(text_idx_to_label_to_memes[text_idx]['hateful']) == 0:
    #     del text_idx_to_label_to_memes[text_idx]['hateful']

print(len(text_idx_to_label_to_memes))
# Out:
# 1043

# %%
list(text_idx_to_label_to_memes.items())[:10]
# Out:
# [(2, {'non-hateful': ['13894', '53027'], 'hateful': ['59817', '96180']}),
#  (8, {'non-hateful': ['02973'], 'hateful': ['39785']}),
#  (13, {'non-hateful': ['19324'], 'hateful': ['95278']}),
#  (21, {'non-hateful': ['70146'], 'hateful': ['20497']}),
#  (37, {'non-hateful': ['51846'], 'hateful': ['28396']}),
#  (38, {'non-hateful': ['01569'], 'hateful': ['83579']}),
#  (40, {'non-hateful': ['06418'], 'hateful': ['83152']}),
#  (48, {'non-hateful': ['34217'], 'hateful': ['74386', '39625']}),
#  (54, {'non-hateful': ['27401'], 'hateful': ['36872']}),
#  (56, {'non-hateful': ['25473'], 'hateful': ['47859']})]

# %%
df.loc['07481']
# Out:
# id                                            07481
# img                                   img/07481.png
# label                                             0
# text        when you see your goat with another man
# split                                         train
# text_idx                                       3154
# Name: 07481, dtype: object

# %%
sample_text_idx = np.random.choice(list(text_idx_to_label_to_memes.keys()))
print(text_idx_to_label_to_memes[sample_text_idx])
meme_idx_1 = np.random.choice(text_idx_to_label_to_memes[sample_text_idx]['non-hateful'])
meme_idx_2 = np.random.choice(text_idx_to_label_to_memes[sample_text_idx]['hateful'])

fig, axes = plt.subplots(1, 2, figsize=(15,10))
axes[0].imshow(Image.open(f'{img_dir}/{meme_idx_1}.png'))
axes[1].imshow(Image.open(f'{img_dir}/{meme_idx_2}.png'))
axes[0].set_title(f'{meme_idx_1}: non-hateful')
axes[1].set_title(f'{meme_idx_2}: hateful')
plt.show()
# Out:
# {'non-hateful': ['57180'], 'hateful': ['83025']}

# %% [markdown]
# # Grouping similar sentences

# %%
import spacy
from multiprocessing import Pool

nlp = spacy.load("en_core_web_md")

from sentence_transformers import SentenceTransformer
model = SentenceTransformer('distilbert-base-nli-mean-tokens')

# %%
def get_simlarity(text1, text2, method='spacy'):
    """
    src: https://stackoverflow.com/questions/65199011/is-there-a-way-to-check-similarity-between-two-full-sentences-in-python
    """

    if method == 'jaccard':
        text1 = set(text1.lower().split(" "))
        text2 = set(text2.lower().split(" "))
        score = len(text1.intersection(text2)) / len(text1.union(text2))
    elif method == 'spacy':
        embed1 = nlp(text1)
        embed2 = nlp(text2)
        score = embed1.similarity(embed2)
    else:
        raise ValueError

    return score

# %%
meme_idx_to_text = df['text'].to_dict()
meme_idxs = list(meme_idx_to_text.keys())
scores = np.zeros((len(meme_idxs), len(meme_idxs)))

for i in tqdm(range(len(meme_idxs))):
    for j in range(i+1, len(meme_idxs)):
        text_i = meme_idx_to_text[meme_idxs[i]]
        text_j = meme_idx_to_text[meme_idxs[j]]
        score = get_simlarity(text_i, text_j, method='jaccard')
        scores[i, j] = score
        scores[j, i] = score

# with Pool(2) as pool:
#     pool.map(compute_similarity, range(len(text_idxs)))
#     # for _ in tqdm(pool.imap_unordered(compute_similarity, text_ids), total=len(text_ids)):
#     #     pass
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
sentences = list(meme_idx_to_text.values())
sentence_embeddings = model.encode(sentences)
print(sentence_embeddings.shape, type(sentence_embeddings))
# Out:
# (10000, 768) <class 'numpy.ndarray'>

# %%
from sklearn.metrics.pairwise import cosine_distances, cosine_similarity
scores_tr = cosine_similarity(sentence_embeddings)
for i in range(len(scores_tr)):
    scores_tr[i, i] = 0
print(scores_tr.shape)
print(scores_tr.min(), scores_tr.max())
# Out:
# (10000, 10000)
# -0.40539545 1.0000005

# %%
i_idxs, j_idxs = np.where((scores>0.7) & (scores_tr>0.7))
print(len(i_idxs))
for i, j in zip(i_idxs[:], j_idxs[:]):
    print(meme_idxs[i], meme_idxs[j],  f'jaccard: {scores[i, j]}; tr: {scores_tr[i, j]}')
    print(meme_idx_to_text[meme_idxs[i]], '\n', meme_idx_to_text[meme_idxs[j]], '\n')
# Out:
# 10518
# 13894 59817 jaccard: 1.0; tr: 1.0000001192092896
# putting bows on your pet
#  putting bows on your pet
#
# 13894 53027 jaccard: 1.0; tr: 1.0000001192092896
# putting bows on your pet
#  putting bows on your pet
#
# 13894 96180 jaccard: 1.0; tr: 0.9999999403953552
# putting bows on your pet
#  putting bows on your pet
#
# 70914 97623 jaccard: 0.8888888888888888; tr: 0.99876868724823
# tattoos are bad for your health i know 5 million people that had tattoos and they all died
#  tattoos are bad for your health i know 5 million people who had tattoos and they all died
#
# 70914 98531 jaccard: 1.0; tr: 0.9999998211860657
# tattoos are bad for your health i know 5 million people that had tattoos and they all died
#  tattoos are bad for your health i know 5 million people that had tattoos and they all died
#
# 02973 39785 jaccard: 1.0; tr: 1.0
# how long can i run? till the chain tightens
#  how long can i run? till the chain tightens
#
# 02973 70426 jaccard: 0.8; tr: 0.9859602451324463
# how long can i run? till the chain tightens
#  how long can he run? till the chain tightens
#
# 58306 50346 jaccard: 0.9523809523809523; tr: 0.999151349067688
# what is he hiding? we need to see his tax returns! let me stop you right there hillary you deleted 30,000 emails, used bleach bit on hard drives, then destroyed phones with hammers you have no right to talk about people hiding anything truth uncensored
#  what is he hiding? we need to see his tax returns! let me stop you right there hillary you deleted 30,000 emails, used bleach bit on hard drives then destroyed phones with hammers you have no right to talk about people hiding anything truth uncensored
#
# 58306 52614 jaccard: 0.9047619047619048; tr: 0.9944331645965576
# what is he hiding? we need to see his tax returns! let me stop you right there hillary you deleted 30,000 emails, used bleach bit on hard drives, then destroyed phones with hammers you have no right to talk about people hiding anything truth uncensored
#  what is he hiding? we need to see his tax returns! let me stop you right there hillary you deleted 30,000 emails, used bleach bit on hard drives, then destroyed phones with hammers you have no right to talk about peopie hiding anything
#
# 19324 95278 jaccard: 1.0; tr: 1.0
# when you're the only dog left at the dog shelter and the black family wants to adopt you
#  when you're the only dog left at the dog shelter and the black family wants to adopt you
#
# 79346 73849 jaccard: 1.0; tr: 1.000000238418579
# voting for hillary is like letting casey anthony watch your kids because she's not guilty
#  voting for hillary is like letting casey anthony watch your kids because she's not guilty
#
# 70146 20497 jaccard: 1.0; tr: 0.9999998807907104
# lets erect a memorial to all the americans murdered by an illegal alien make it 1,500 miles long 30 feet tall and put it on the southern border
#  lets erect a memorial to all the americans murdered by an illegal alien make it 1,500 miles long 30 feet tall and put it on the southern border
#
# 97180 65207 jaccard: 1.0; tr: 0.9339289665222168
# if there is no race it can't be homicide
#  it can't be homicide if there is no race
#
# 97180 29357 jaccard: 1.0; tr: 0.933925211429596
# if there is no race it can't be homicide
#  it can't be homicide if there is no race
#
# 97180 67801 jaccard: 1.0; tr: 1.0
# if there is no race it can't be homicide
#  if there is no race it can't be homicide
#
# 15872 42816 jaccard: 0.8333333333333334; tr: 0.9741368889808655
# when you come home from a long day of suicide bombinb and your wife gives you this look
#  this look your wife gives you when you come home from a long day of suicide bombing
#
# 72598 29587 jaccard: 1.0; tr: 1.0
# texas churches be like... pew pew pew
#  texas churches be like... pew pew pew
#
# 51846 28396 jaccard: 1.0; tr: 0.9999999403953552
# doesn't wear tampons because she trips over the string
#  doesn't wear tampons because she trips over the string
#
# 01569 83579 jaccard: 1.0; tr: 1.0
# when you can't decide to pre heat the oven or just throw the meal in right away
#  when you can't decide to pre heat the oven or just throw the meal in right away
#
# 06418 83152 jaccard: 1.0; tr: 1.0
# 1 bomb every minute
#  1 bomb every minute
#
# 86354 13856 jaccard: 1.0; tr: 1.0
# officer down
#  officer down
#
# 86354 18946 jaccard: 1.0; tr: 1.0
# officer down
#  officer down
#
# 74386 63548 jaccard: 0.8571428571428571; tr: 0.8510502576828003
# we said we would never forget why are you voting them into our government?
#  we said we would never forget why are you voting them into our governement?
#
# 74386 34217 jaccard: 1.0; tr: 0.9999998807907104
# we said we would never forget why are you voting them into our government?
#  we said we would never forget why are you voting them into our government?
#
# 74386 39625 jaccard: 1.0; tr: 0.9999998807907104
# we said we would never forget why are you voting them into our government?
#  we said we would never forget why are you voting them into our government?
#
# 74386 68730 jaccard: 0.8571428571428571; tr: 0.9893626570701599
# we said we would never forget why are you voting them into our government?
#  we said we would never forget why are you voting then into our government?
#
# 74386 01936 jaccard: 0.8571428571428571; tr: 0.8510502576828003
# we said we would never forget why are you voting them into our government?
#  we said we would never forget why are you voting them into our governement?
#
# 59613 92617 jaccard: 0.8; tr: 0.9962747097015381
# when a porn video features a tranny but then' she' turns out to be a midget too you had my curiosity but now you have my attention
#  when the porn video features a tranny but then 'she' turns out to be a midget too you had my curiosity but now you have my attention
#
# 59613 56421 jaccard: 0.8; tr: 0.9962747097015381
# when a porn video features a tranny but then' she' turns out to be a midget too you had my curiosity but now you have my attention
#  when the porn video features a tranny but then 'she' turns out to be a midget too you had my curiosity but now you have my attention
#
# 48279 91286 jaccard: 0.9090909090909091; tr: 0.976057231426239
# nice watch must have cost an arm and a leg
#  nice watch it must have cost an arm and a leg
#
# 27401 36872 jaccard: 1.0; tr: 0.9999998807907104
# for the last time.. i'm not michelle obama
#  for the last time.. i'm not michelle obama
#
# 25473 47859 jaccard: 1.0; tr: 0.9999998807907104
# and then i told them you're going on a fun camping trip
#  and then i told them you're going on a fun camping trip
#
# 69357 79036 jaccard: 1.0; tr: 1.0
# hey look at me! i'm a serial pedofile
#  hey look at me! i'm a serial pedofile
#
# 81059 93572 jaccard: 1.0; tr: 0.9999998807907104
# i like my refugees like this '' '' ''
#  i like my refugees like this '' '' ''
#
# 74530 67894 jaccard: 0.7058823529411765; tr: 0.9745451211929321
# what's the difference between a jew and a pizza? a pizza doesn't scream when you put it in the oven
#  what's the difference between a jew and a pizza a pizza doesn't scream in the oven
#
# 74530 52469 jaccard: 0.7058823529411765; tr: 0.9745451211929321
# what's the difference between a jew and a pizza? a pizza doesn't scream when you put it in the oven
#  what's the difference between a jew and a pizza a pizza doesn't scream in the oven
#
# 46127 48976 jaccard: 1.0; tr: 0.9353255033493042
# "ay, tone. how'd da gas stay in if da door is made of wood?"
#  gas stay in if da door "ay, tone. how'd da is made of wood?"
#
# 87594 86139 jaccard: 0.9523809523809523; tr: 0.9852545857429504
# what do i have in common with cow pies? the older we get, the easier for you to pick us up!
#  what do i have in common with cow pies? xxx the older we get, the easier for you to pick us up!
#
# 12548 89607 jaccard: 1.0; tr: 0.9999997615814209
# running chocolate
#  running chocolate
#
# 29163 90573 jaccard: 1.0; tr: 1.0000001192092896
# what kind of punch can take out 20 kids and 6 adults? a sandy hook
#  what kind of punch can take out 20 kids and 6 adults? a sandy hook
#
# 29163 70492 jaccard: 0.8235294117647058; tr: 1.0
# what kind of punch can take out 20 kids and 6 adults? a sandy hook
#  what kind of punch can take out 20 kids and 6 adults ? a sandy hook
#
# 29163 92154 jaccard: 1.0; tr: 1.0000001192092896
# what kind of punch can take out 20 kids and 6 adults? a sandy hook
#  what kind of punch can take out 20 kids and 6 adults? a sandy hook
#
# 90583 09867 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 30598 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 36508 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 25340 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 51462 jaccard: 1.0; tr: 0.9999998807907104
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 12490 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 54981 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 57982 jaccard: 1.0; tr: 0.9999998807907104
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 75291 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 28154 jaccard: 1.0; tr: 0.9999998807907104
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 46239 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 80156 jaccard: 1.0; tr: 0.9999998807907104
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 72834 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 90583 32658 jaccard: 1.0; tr: 0.9999999403953552
# we can kill as many as we want and your stupid government keeps bringing us in
#  we can kill as many as we want and your stupid government keeps bringing us in
#
# 38612 48015 jaccard: 1.0; tr: 1.0
# so there is this new implant that can actually fix stupid
#  so there is this new implant that can actually fix stupid
#
# 15803 04397 jaccard: 1.0; tr: 0.9923236966133118
# what do you call a retarded jew? auschwistic
#  what do you call a a retarded jew? auschwistic
#
# 18350 51403 jaccard: 1.0; tr: 0.9999998807907104
# when you see the gas bill
#  when you see the gas bill
#
# 18350 60721 jaccard: 1.0; tr: 0.9999998807907104
# when you see the gas bill
#  when you see the gas bill
#
# 18350 68921 jaccard: 1.0; tr: 0.9999998807907104
# when you see the gas bill
#  when you see the gas bill
#
# 91547 98457 jaccard: 1.0; tr: 0.9999996423721313
# cheers to all the people who can change their minds when presented with information that contradicts their beliefs
#  cheers to all the people who can change their minds when presented with information that contradicts their beliefs
#
# 93741 82563 jaccard: 0.8; tr: 0.9697970747947693
# stop being a bitch
#  stop being a little bitch
#
# 93741 38145 jaccard: 0.8; tr: 0.9697970747947693
# stop being a bitch
#  stop being a little bitch
#
# 05384 64708 jaccard: 1.0; tr: 0.9999998807907104
# spending quality time with dad
#  spending quality time with dad
#
# 01845 06584 jaccard: 1.0; tr: 1.0
# when you consume too much trans fat
#  when you consume too much trans fat
#
# 80521 01829 jaccard: 0.8571428571428571; tr: 0.9952351450920105
# him: the dishwasher is acting weird her: what's it doing? him: chopping fucking vegetables
#  him: the dishwasher is acting weird her: what's it doing him: chopping fucking vegetables
#
# 80521 74862 jaccard: 1.0; tr: 1.0
# him: the dishwasher is acting weird her: what's it doing? him: chopping fucking vegetables
#  him: the dishwasher is acting weird her: what's it doing? him: chopping fucking vegetables
#
# 34165 36075 jaccard: 1.0; tr: 1.0000001192092896
# be happy you dont have neanderthal dna
#  be happy you dont have neanderthal dna
#
# 09617 86714 jaccard: 1.0; tr: 1.0
# when you turn on the light and realize you have been fisting the wrong hole
#  when you turn on the light and realize you have been fisting the wrong hole
#
# 96258 41263 jaccard: 0.9090909090909091; tr: 0.9450868964195251
# its national hebrew day go pick up a hot girl
#  its national hebrew day go pick up a hot jewish girl
#
# 96258 79125 jaccard: 0.9090909090909091; tr: 0.9999998211860657
# its national hebrew day go pick up a hot girl
#  its national hebrew day   go pick up a hot girl
#
# 96258 70432 jaccard: 0.9090909090909091; tr: 0.9450868964195251
# its national hebrew day go pick up a hot girl
#  its national hebrew day go pick up a hot jewish girl
#
# 57349 06825 jaccard: 1.0; tr: 0.9999998807907104
# "at first, i didn t want to wear a hijab." "but my husband convinced me otherwise."
#  "at first, i didn t want to wear a hijab." "but my husband convinced me otherwise."
#
# 20568 35097 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 97542 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 91562 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 02947 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 94850 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 92180 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 48136 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 69842 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 07463 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 91270 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 64781 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 96078 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 97162 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 74380 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 34518 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 17834 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 81692 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 68231 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 98517 jaccard: 1.0; tr: 0.9941833019256592
# meanwhile at the isis strip club
#  at the isis strip club meanwhile
#
# 20568 25780 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 27156 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 39170 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 71368 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 50624 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 29013 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 85173 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 10793 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 15072 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 01348 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 92845 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 25913 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 95401 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 31408 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 56134 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 82169 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 70269 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 01236 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 36804 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 68954 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 71658 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 03847 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 05914 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 58732 jaccard: 1.0; tr: 0.9999998807907104
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 20568 34816 jaccard: 1.0; tr: 1.0000001192092896
# meanwhile at the isis strip club
#  meanwhile at the isis strip club
#
# 84269 67125 jaccard: 1.0; tr: 1.000000238418579
# just ordered the new anne frank puzzle
#  just ordered the new anne frank puzzle
#
# 84269 24567 jaccard: 1.0; tr: 1.000000238418579
# just ordered the new anne frank puzzle
#  just ordered the new anne frank puzzle
#
# 68079 07486 jaccard: 1.0; tr: 1.0000004768371582
# what's the difference between a walrus and a lesbian? one smells like fish and has a moustache and the other is a walrus!
#  what's the difference between a walrus and a lesbian? one smells like fish and has a moustache and the other is a walrus!
#
# 54102 21408 jaccard: 0.8095238095238095; tr: 0.9875321388244629
# i'm uncertain where i stand on abortion i like the killing babies but hate the idea of giving women a choice
#  i'm uncertain where i stand on abortion.. i like killing babies, but hate the idea of giving women a choice
#
# 54102 15064 jaccard: 0.8095238095238095; tr: 0.988481342792511
# i'm uncertain where i stand on abortion i like the killing babies but hate the idea of giving women a choice
#  i'm uncertain where i stand on abortion. i like killing babies, but hate the idea of giving women a choice
#
# 63710 68971 jaccard: 1.0; tr: 0.9999998807907104
# literally nobody: white people sitting at the bar: can you put it on the golf channel??
#  literally nobody: white people sitting at the bar: can you put it on the golf channel??
#
# 63710 64127 jaccard: 1.0; tr: 1.0000001192092896
# literally nobody: white people sitting at the bar: can you put it on the golf channel??
#  literally nobody: white people sitting at the bar: can you put it on the golf channel??
#
# 74391 64385 jaccard: 1.0; tr: 0.9999999403953552
# there must be some way this victimizes me
#  there must be some way this victimizes me
#
# 26759 50427 jaccard: 1.0; tr: 0.9999998807907104
# that look when you wanna cut a bitch but you remember your a changed man
#  that look when you wanna cut a bitch but you remember your a changed man
#
# 27398 67059 jaccard: 1.0; tr: 0.9999998211860657
# if you believe that, i've got a virgin goat to sell you!
#  if you believe that, i've got a virgin goat to sell you!
#
# 18730 73069 jaccard: 1.0; tr: 0.9999998807907104
# immigration invasion learn the difference
#  immigration invasion learn the difference
#
# 91754 98461 jaccard: 1.0; tr: 1.0000001192092896
# when you finally buy a dishwasher this works a lot better than a sponge
#  when you finally buy a dishwasher this works a lot better than a sponge
#
# 18673 75230 jaccard: 0.8571428571428571; tr: 0.9938321113586426
# how to remember kid in hot car keep 2nd road beer with them
#  how to remember kid in hot car keep 2nd road beer with them!
#
# 18673 80652 jaccard: 1.0; tr: 1.0000001192092896
# how to remember kid in hot car keep 2nd road beer with them
#  how to remember kid in hot car keep 2nd road beer with them
#
# 18673 89532 jaccard: 0.8571428571428571; tr: 0.993842363357544
# how to remember kid in hot car keep 2nd road beer with them
#  how to remember kid in hot car keep 2nd road beer with them!
#
# 59073 71230 jaccard: 1.0; tr: 1.0000001192092896
# the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#  the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#
# 59073 04986 jaccard: 0.8181818181818182; tr: 0.9914493560791016
# the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#  the enemy within linda sarsour ocasio-cortez rashida tlaib ilhan omar
#
# 59073 17548 jaccard: 1.0; tr: 1.0
# the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#  the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#
# 59073 53249 jaccard: 0.7692307692307693; tr: 0.7416311502456665
# the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#  the enemy has infiltrated congress the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#
# 59073 30289 jaccard: 0.8181818181818182; tr: 0.9971393346786499
# the enemy within ilhan omar linda sarsour rashida tlaib ocasto-cortez
#  the enemy within ilhan omar linda sarsour rashida tlaib ocasio-cortez
#
# 28405 09624 jaccard: 1.0; tr: 1.0
# white people already paid reparations
#  white people already paid reparations
#
# 78351 02431 jaccard: 1.0; tr: 0.9999998211860657
# subway is similar to prostitution you pay someone else to do your wife's job
#  subway is similar to prostitution you pay someone else to do your wife's job
#
# 71436 08469 jaccard: 1.0; tr: 0.9999998807907104
# trump supporters be like mexicans stole my teeth
#  trump supporters be like mexicans stole my teeth
#
# 71436 76532 jaccard: 1.0; tr: 0.9999998807907104
# trump supporters be like mexicans stole my teeth
#  trump supporters be like mexicans stole my teeth
#
# 20736 51763 jaccard: 1.0; tr: 1.000000238418579
# go be gay somewhere else
#  go be gay somewhere else
#
# 20736 20654 jaccard: 1.0; tr: 1.000000238418579
# go be gay somewhere else
#  go be gay somewhere else
#
# 34901 50293 jaccard: 1.0; tr: 0.9484118223190308
# gays aids it really be like that
#  aids gays it really be like that
#
# 28793 19230 jaccard: 1.0; tr: 1.0
# congratulations it's non binary
#  congratulations it's non binary
#
# 05172 93685 jaccard: 1.0; tr: 1.0
# islam is the religion of peace! if you don't agree i kill you!
#  islam is the religion of peace! if you don't agree i kill you!
#
# 98501 60578 jaccard: 1.0; tr: 0.9999998807907104
# send me sexy pic
#  send me sexy pic
#
# 43612 37184 jaccard: 1.0; tr: 0.9999998807907104
# racing for pink slips in africa
#  racing for pink slips in africa
#
# 43612 40216 jaccard: 1.0; tr: 0.9999998807907104
# racing for pink slips in africa
#  racing for pink slips in africa
#
# 43612 85461 jaccard: 1.0; tr: 0.9999998807907104
# racing for pink slips in africa
#  racing for pink slips in africa
#
# 43612 51726 jaccard: 1.0; tr: 0.9999998807907104
# racing for pink slips in africa
#  racing for pink slips in africa
#
# 43612 94580 jaccard: 0.8571428571428571; tr: 0.9019845128059387
# racing for pink slips in africa
#  racing for pink slips in south africa
#
# 43612 14083 jaccard: 0.8571428571428571; tr: 0.9019824266433716
# racing for pink slips in africa
#  racing for pink slips in south africa
#
# 43612 79612 jaccard: 1.0; tr: 0.9999998807907104
# racing for pink slips in africa
#  racing for pink slips in africa
#
# 15480 45987 jaccard: 0.8666666666666667; tr: 0.9919052124023438
# we kill you on 9/11 and you elect 3 of us to congress, stupid infidels!
#  we kill you on 9/11 and you elect 3 of us to congress stupid infidels!
#
# 81069 51903 jaccard: 1.0; tr: 0.9999998807907104
# when you bout to nut in your cousin and you hear the barn door open
#  when you bout to nut in your cousin and you hear the barn door open
#
# 72584 31290 jaccard: 1.0; tr: 0.9999999403953552
# 9 months before i was born i went to a party with my dad and left with my mom
#  9 months before i was born i went to a party with my dad and left with my mom
#
# 51763 20736 jaccard: 1.0; tr: 1.000000238418579
# go be gay somewhere else
#  go be gay somewhere else
#
# 51763 20654 jaccard: 1.0; tr: 1.000000238418579
# go be gay somewhere else
#  go be gay somewhere else
#
# 06873 84502 jaccard: 1.0; tr: 1.0000003576278687
# just got a bootleg copy of muslim porn deep goat
#  just got a bootleg copy of muslim porn deep goat
#
# 06359 97501 jaccard: 1.0; tr: 0.9999999403953552
# what women think they'll do when the economy collapses vs what they'll actually do
#  what women think they'll do when the economy collapses vs what they'll actually do
#
# 06359 87934 jaccard: 1.0; tr: 1.000000238418579
# what women think they'll do when the economy collapses vs what they'll actually do
#  what women think they'll do when the economy collapses vs what they'll actually do
#
# 06359 30486 jaccard: 1.0; tr: 0.9999999403953552
# what women think they'll do when the economy collapses vs what they'll actually do
#  what women think they'll do when the economy collapses vs what they'll actually do
#
# 76250 45016 jaccard: 1.0; tr: 1.0000001192092896
# chillin with my chromies
#  chillin with my chromies
#
# 61952 23198 jaccard: 1.0; tr: 0.9999998807907104
# what i say about the gunman every time there's a mass shooting
#  what i say about the gunman every time there's a mass shooting
#
# 61952 62589 jaccard: 1.0; tr: 0.9999998807907104
# what i say about the gunman every time there's a mass shooting
#  what i say about the gunman every time there's a mass shooting
#
# 61952 27861 jaccard: 1.0; tr: 0.9999998807907104
# what i say about the gunman every time there's a mass shooting
#  what i say about the gunman every time there's a mass shooting
#
# 80269 98416 jaccard: 1.0; tr: 0.9999997615814209
# this is really out of mein kampfert zone
#  this is really out of mein kampfert zone
#
# 05712 57120 jaccard: 1.0; tr: 1.0
# god will forgive you no matter what you've done sweet
#  god will forgive you no matter what you've done sweet
#
# 35219 18597 jaccard: 1.0; tr: 0.9999999403953552
# they stole ma chickin i stole their life
#  they stole ma chickin i stole their life
#
# 35219 10259 jaccard: 1.0; tr: 0.9999999403953552
# they stole ma chickin i stole their life
#  they stole ma chickin i stole their life
#
# 90146 43716 jaccard: 1.0; tr: 1.0000001192092896
# all races are equal
#  all races are equal
#
# 90146 09364 jaccard: 1.0; tr: 0.9999998211860657
# all races are equal
#  all races are equal
#
# 51278 21547 jaccard: 1.0; tr: 0.9999998807907104
# when you haven't stolen anything in a week
#  when you haven't stolen anything in a week
#
# 51278 32915 jaccard: 1.0; tr: 0.9999998807907104
# when you haven't stolen anything in a week
#  when you haven't stolen anything in a week
#
# 51278 71058 jaccard: 1.0; tr: 0.9999998807907104
# when you haven't stolen anything in a week
#  when you haven't stolen anything in a week
#
# 65213 16048 jaccard: 1.0; tr: 0.9999996423721313
# what your ancestors were doing july 4, 1776 what dummies do today for july 4th
#  what your ancestors were doing july 4, 1776 what dummies do today for july 4th
#
# 58426 31029 jaccard: 1.0; tr: 1.0
# when there is no pinyata at the party but the emo kid just hung himself improvise. adapt. overcome
#  when there is no pinyata at the party but the emo kid just hung himself improvise. adapt. overcome
#
# 96785 52947 jaccard: 1.0; tr: 1.0
# lost african tribe
#  lost african tribe
#
# 93826 05869 jaccard: 1.0; tr: 1.0
# my wife asked me where i'd like to be buried apparently, "balls deep in your sister" wasn't the answer she was expecting
#  my wife asked me where i'd like to be buried apparently, "balls deep in your sister" wasn't the answer she was expecting
#
# 84072 43608 jaccard: 1.0; tr: 1.0
# when you're fucking but wanna make sure he's not stealing anything
#  when you're fucking but wanna make sure he's not stealing anything
#
# 91708 17932 jaccard: 1.0; tr: 1.0000001192092896
# when mohamed puts it inside
#  when mohamed puts it inside
#
# 86491 09814 jaccard: 1.0; tr: 0.9999998211860657
# you are not wanted! you are a mental deficient!
#  you are not wanted! you are a mental deficient!
#
# 81734 38209 jaccard: 1.0; tr: 1.0
# when instincts take over
#  when instincts take over
#
# 80247 08275 jaccard: 1.0; tr: 1.0
# the pimp hand strong enough for man but made for teaching
#  the pimp hand strong enough for man but made for teaching
#
# 50793 19406 jaccard: 1.0; tr: 1.0
# a muslim in congress wants to get rid of homeland security let that sink in
#  a muslim in congress wants to get rid of homeland security let that sink in
#
# 13857 62904 jaccard: 1.0; tr: 1.0
# this is why we shoot you guys
#  this is why we shoot you guys
#
# 13857 24980 jaccard: 0.75; tr: 0.9246819019317627
#
# 15649 09176 jaccard: 0.8888888888888888; tr: 0.9030145406723022
# be kind to those less fortunate than you
#  always be kind to those less fortunate than you
#
# 51460 85936 jaccard: 1.0; tr: 1.0
# love is love respect
#  love is love respect
#
# 79315 71294 jaccard: 1.0; tr: 0.9999998807907104
# laughs in 52% of us crime rate
#  laughs in 52% of us crime rate
#
# 79315 23807 jaccard: 1.0; tr: 0.9999998807907104
# laughs in 52% of us crime rate
#  laughs in 52% of us crime rate
#
# 03241 32615 jaccard: 1.0; tr: 0.9999998807907104
# when black people make white jokes when white people make black jokes
#  when black people make white jokes when white people make black jokes
#
# 03241 63520 jaccard: 1.0; tr: 0.9999998807907104
# when black people make white jokes when white people make black jokes
#  when black people make white jokes when white people make black jokes
#
# 38041 03871 jaccard: 1.0; tr: 1.0
# justin trudeau the imam of canada
#  justin trudeau the imam of canada
#
# 38041 69041 jaccard: 1.0; tr: 1.0
# justin trudeau the imam of canada
#  justin trudeau the imam of canada
#
# 36974 82179 jaccard: 0.8; tr: 0.9919068813323975
# do you have any idea how black you were going?
#  do you have any idea how black you were going
#
# 36974 34079 jaccard: 1.0; tr: 1.0000001192092896
# do you have any idea how black you were going?
#  do you have any idea how black you were going?
#
# 36974 25781 jaccard: 0.8; tr: 0.9919149279594421
# do you have any idea how black you were going?
#  do you have any idea how black you were going
#
# 81546 34186 jaccard: 1.0; tr: 1.0000001192092896
# when i was a kid i thought black people were made from anal sex
#  when i was a kid i thought black people were made from anal sex
#
# 48703 01653 jaccard: 1.0; tr: 1.0
# a girl asks her mom, "why am i black and you're white?" she says, "the way that party went, you're lucky you don't bark. "
#  a girl asks her mom, "why am i black and you're white?" she says, "the way that party went, you're lucky you don't bark. "
#
# 48703 61037 jaccard: 1.0; tr: 1.0
# a girl asks her mom, "why am i black and you're white?" she says, "the way that party went, you're lucky you don't bark. "
#  a girl asks her mom, "why am i black and you're white?" she says, "the way that party went, you're lucky you don't bark. "
#
# 42319 76510 jaccard: 0.8571428571428571; tr: 0.9989091753959656
# chelsea clinton.. so ugly that when she gives head, it counts as anal
#  chelsea clinton... so ugly that when she gives head, it counts as anal
#
# 42319 17469 jaccard: 1.0; tr: 1.0000001192092896
# chelsea clinton.. so ugly that when she gives head, it counts as anal
#  chelsea clinton.. so ugly that when she gives head, it counts as anal
#
# 42319 45608 jaccard: 0.8571428571428571; tr: 0.9989091753959656
# chelsea clinton.. so ugly that when she gives head, it counts as anal
#  chelsea clinton... so ugly that when she gives head, it counts as anal
#
# 61234 51928 jaccard: 1.0; tr: 1.0
# i could have annihilated all of them but i left some of them alive so you will know why i was killing them
#  i could have annihilated all of them but i left some of them alive so you will know why i was killing them
#
# 49630 71950 jaccard: 1.0; tr: 1.0000001192092896
# if they aren't meant to cook why do they have eggs and milk inside them
#  if they aren't meant to cook why do they have eggs and milk inside them
#
# 60173 71826 jaccard: 1.0; tr: 1.000000238418579
# white people dont shoot eachother in the streets like black people do we do it in schools, because we have class
#  white people dont shoot eachother in the streets like black people do we do it in schools, because we have class
#
# 68423 09486 jaccard: 0.875; tr: 0.9032591581344604
# don't get me started about your tranny problems
#  don't get me started about your problems
#
# 68423 84527 jaccard: 1.0; tr: 1.000000238418579
# don't get me started about your tranny problems
#  don't get me started about your tranny problems
#
# 39652 40967 jaccard: 0.8333333333333334; tr: 0.934012234210968
# donald trump proving you don't have to be poor to be trailer trash
#  donald trump proving you don't have to be poor to be white trash
#
# 70435 54713 jaccard: 1.0; tr: 0.9999997615814209
# this one time at camp we got so baked
#  this one time at camp we got so baked
#
# 70435 13986 jaccard: 1.0; tr: 0.9999997019767761
# this one time at camp we got so baked
#  this one time at camp we got so baked
#
# 70435 49387 jaccard: 1.0; tr: 1.0
# this one time at camp we got so baked
#  this one time at camp we got so baked
#
# 70435 95078 jaccard: 1.0; tr: 1.0
# this one time at camp we got so baked
#  this one time at camp we got so baked
#
# 70435 68342 jaccard: 1.0; tr: 0.9999997615814209
# this one time at camp we got so baked
#  this one time at camp we got so baked
#
# 70435 53108 jaccard: 1.0; tr: 0.9999997019767761
# this one time at camp we got so baked
# ...
#  they were mentally ill. i had to cure them
#
# 94302 48652 jaccard: 1.0; tr: 1.0000001192092896
# we can end racism if we end a race
#  we can end racism if we end a race
#
# 42036 27318 jaccard: 1.0; tr: 0.9999997019767761
# over heard my daughter telling her friend she was curious what it would be like to date a black guy so ... i showed her!
#  over heard my daughter telling her friend she was curious what it would be like to date a black guy so ... i showed her!
#
# 69487 42308 jaccard: 1.0; tr: 1.0000001192092896
# don't be racist black and white children are the same
#  don't be racist black and white children are the same
#
# 05978 73615 jaccard: 1.0; tr: 1.000000238418579
# i think it is safe now challenge accepted
#  i think it is safe now challenge accepted
#
# 23075 23187 jaccard: 1.0; tr: 0.9999998807907104
# when your teacher roasts you and your homie but he doesn't know about the bomb that's going off in 2 mins
#  when your teacher roasts you and your homie but he doesn't know about the bomb that's going off in 2 mins
#
# 97546 69308 jaccard: 0.9; tr: 0.9884885549545288
# texting and flying what's the worst that could happen?
#  texting and flying n what's the worst that could happen?
#
# 73841 52974 jaccard: 1.0; tr: 0.9999998807907104
# which jewish girl is hotter?
#  which jewish girl is hotter?
#
# 73841 53678 jaccard: 1.0; tr: 0.9999999403953552
# which jewish girl is hotter?
#  which jewish girl is hotter?
#
# 73841 85912 jaccard: 1.0; tr: 0.9999999403953552
# which jewish girl is hotter?
#  which jewish girl is hotter?
#
# 74031 06985 jaccard: 1.0; tr: 0.9999998807907104
# their average iq is about 70-80, few points above being retarded
#  their average iq is about 70-80, few points above being retarded
#
# 58467 45976 jaccard: 1.0; tr: 0.9999999403953552
# terrorism is one of the only areas where they do most of the work and none of them get the credit
#  terrorism is one of the only areas where they do most of the work and none of them get the credit
#
# 68039 81690 jaccard: 1.0; tr: 1.0000001192092896
# when black people think it's funny to steal a white man's bike
#  when black people think it's funny to steal a white man's bike
#
# 62490 92547 jaccard: 1.0; tr: 1.000000238418579
# 1939-1945 bake off winner
#  1939-1945 bake off winner
#
# 82507 38410 jaccard: 0.8571428571428571; tr: 0.9959786534309387
# me: want some ribs? chinese person: no me: want some ribs made from house pets? chinese person:
#  "me: want some ribs? chinese person: no me: want some ribs made from house pets? chinese person: "
#
# 52710 38029 jaccard: 1.0; tr: 0.9999998807907104
# loading the dishwasher in the back solid move
#  loading the dishwasher in the back solid move
#
# 16827 50129 jaccard: 1.0; tr: 0.9999999403953552
# partial arts
#  partial arts
#
# 16827 71459 jaccard: 1.0; tr: 0.9999999403953552
# partial arts
#  partial arts
#
# 16827 61752 jaccard: 1.0; tr: 0.9999999403953552
# partial arts
#  partial arts
#
# 19346 86193 jaccard: 1.0; tr: 0.9999997615814209
# these women have access to top secret classified information let that sink in
#  these women have access to top secret classified information let that sink in
#
# 16904 83924 jaccard: 1.0; tr: 1.0
# than nasty i'd rather be deplorable
#  than nasty i'd rather be deplorable
#
# 06231 69234 jaccard: 1.0; tr: 0.9999997019767761
# do i need to dig up hitler to show you how to use an oven
#  do i need to dig up hitler to show you how to use an oven
#
# 43127 74265 jaccard: 1.0; tr: 1.0000001192092896
# it's taekwondo, not taekwondon't
#  it's taekwondo, not taekwondon't
#
# 76913 26418 jaccard: 1.0; tr: 0.9999999403953552
# 4 years for your bachelors? i worked 60 years for my masters
#  4 years for your bachelors? i worked 60 years for my masters
#
# 87923 84321 jaccard: 1.0; tr: 1.0
# there's a 50% chance this phone is stolen
#  there's a 50% chance this phone is stolen
#
# 59031 76180 jaccard: 1.0; tr: 1.0
# how to get stoned without smoking weed
#  how to get stoned without smoking weed
#
# 17539 25639 jaccard: 0.8181818181818182; tr: 0.969794750213623
# why isn't my drain working? probably because the pipe's black
#  why isn't my drain working? probably cause the pipe's black
#
# 17539 63295 jaccard: 0.8181818181818182; tr: 0.969794750213623
# why isn't my drain working? probably because the pipe's black
#  why isn't my drain working? probably cause the pipe's black
#
# 92783 84305 jaccard: 1.0; tr: 1.0
# what's better than winning a gold medal in this contest walking
#  what's better than winning a gold medal in this contest walking
#
# 51890 46172 jaccard: 0.8333333333333334; tr: 0.9965356588363647
# "how we see muslims how muslims see us
#  how we see muslims how muslims see us
#
# 51890 50184 jaccard: 0.8333333333333334; tr: 0.9965377449989319
# "how we see muslims how muslims see us
#  how we see muslims how muslims see us
#
# 51890 70624 jaccard: 0.8333333333333334; tr: 0.9965356588363647
# "how we see muslims how muslims see us
#  how we see muslims how muslims see us
#
# 51890 08652 jaccard: 0.8333333333333334; tr: 0.9965356588363647
# "how we see muslims how muslims see us
#  how we see muslims how muslims see us
#
# 34678 35796 jaccard: 1.0; tr: 1.0000001192092896
# i hate it when white people throw gang signs thinking they're black and shit
#  i hate it when white people throw gang signs thinking they're black and shit
#
# 91740 58604 jaccard: 0.75; tr: 0.9479984641075134
# i got 99 problems and chromosomes
#  i got 99 problems and chromosomes are one
#
# 91740 69043 jaccard: 0.7142857142857143; tr: 0.9855215549468994
# i got 99 problems and chromosomes
#  1 got 99 problems and chromosomes
#
# 91740 32608 jaccard: 0.7142857142857143; tr: 0.8595118522644043
# i got 99 problems and chromosomes
#  i got 99 problems and optimisim
#
# 91740 40728 jaccard: 1.0; tr: 1.0
# i got 99 problems and chromosomes
#  i got 99 problems and chromosomes
#
# 53942 58716 jaccard: 1.0; tr: 1.0
# they are like manure spread them out and they help everything grow better, but keep them in one big pile and they stink horribly
#  they are like manure spread them out and they help everything grow better, but keep them in one big pile and they stink horribly
#
# 38674 26738 jaccard: 1.0; tr: 0.9999999403953552
# blacks are musical they always love a good beat
#  blacks are musical they always love a good beat
#
# 54098 73021 jaccard: 1.0; tr: 1.0
# when mom asks where all the jews went
#  when mom asks where all the jews went
#
# 54098 09467 jaccard: 1.0; tr: 1.0
# when mom asks where all the jews went
#  when mom asks where all the jews went
#
# 54098 20974 jaccard: 1.0; tr: 1.0
# when mom asks where all the jews went
#  when mom asks where all the jews went
#
# 61304 75139 jaccard: 0.9090909090909091; tr: 0.929858922958374
# mom won't let me use the oven with my friends
#  mom won't let me use the oven with my jewish friends
#
# 61304 87054 jaccard: 0.9090909090909091; tr: 0.9298892617225647
# mom won't let me use the oven with my friends
#  mom won't let me use the oven with my jewish friends
#
# 61304 04583 jaccard: 0.9090909090909091; tr: 0.929858922958374
# mom won't let me use the oven with my friends
#  mom won't let me use the oven with my jewish friends
#
# 61597 74920 jaccard: 1.0; tr: 0.9999998807907104
# when you realize you're pregnant because you pull out your tampon but all the cotton was mysteriously picked off
#  when you realize you're pregnant because you pull out your tampon but all the cotton was mysteriously picked off
#
# 21497 34768 jaccard: 1.0; tr: 0.9999998211860657
# what a true rapist looks like
#  what a true rapist looks like
#
# 31569 83246 jaccard: 0.8571428571428571; tr: 0.9536912441253662
# why don't they eat pussy? because it's too close to the gas chamber
#  why don't jews eat pussy? because it's too close to the gas chamber
#
# 31569 30576 jaccard: 1.0; tr: 0.9578834772109985
# why don't they eat pussy? because it's too close to the gas chamber
#  why don't they eat pussy? too close because it's to the gas chamber
#
# 72415 71830 jaccard: 0.7647058823529411; tr: 0.9928684234619141
# what's the difference between the 2? the first one can't sing when you put chains on it
#  "what's the difference between the 2? the first one can't sing when you put chains on it"
#
# 21640 71832 jaccard: 1.0; tr: 1.0
# when a waitress dates the new dishwasher
#  when a waitress dates the new dishwasher
#
# 06348 59264 jaccard: 1.0; tr: 1.0
# the look you give when your husband would rather fuck a goat then you
#  the look you give when your husband would rather fuck a goat then you
#
# 34297 54683 jaccard: 1.0; tr: 1.000000238418579
# feeling cute. might kill 6 million later...idk
#  feeling cute. might kill 6 million later...idk
#
# 90382 08541 jaccard: 1.0; tr: 0.9999998807907104
# when your test comes back and you got a 47 out of 46
#  when your test comes back and you got a 47 out of 46
#
# 60895 20918 jaccard: 1.0; tr: 0.9999998807907104
# what every arab in sydney looks like
#  what every arab in sydney looks like
#
# 12536 47532 jaccard: 1.0; tr: 1.000000238418579
# turning every country it touches into a shithole
#  turning every country it touches into a shithole
#
# 07596 36521 jaccard: 1.0; tr: 1.0
# the face you make when one of those damn apes cancels your show
#  the face you make when one of those damn apes cancels your show
#
# 80916 80425 jaccard: 1.0; tr: 0.9999999403953552
# the guy who created the joke the jokers
#  the guy who created the joke the jokers
#
# 54196 70214 jaccard: 1.0; tr: 1.0
# let's not be hasty. the worldview of the guys who created this grisly spectacle of mass-murder could be any number of- comedy aaaaaannnd it's these guys
#  let's not be hasty. the worldview of the guys who created this grisly spectacle of mass-murder could be any number of- comedy aaaaaannnd it's these guys
#
# 78965 20165 jaccard: 1.0; tr: 1.0
# how white liberals treat minorities who don't vote democrat
#  how white liberals treat minorities who don't vote democrat
#
# 86529 80379 jaccard: 1.0; tr: 0.9999999403953552
# when your dad comes home from a suicide bombing
#  when your dad comes home from a suicide bombing
#
# 86529 59287 jaccard: 1.0; tr: 0.9999999403953552
# when your dad comes home from a suicide bombing
#  when your dad comes home from a suicide bombing
#
# 67350 91236 jaccard: 1.0; tr: 1.000000238418579
# turn your dishwasher into a snow remover
#  turn your dishwasher into a snow remover
#
# 17805 93874 jaccard: 1.0; tr: 1.000000238418579
# allah! my goat doesn't love me anymore!
#  allah! my goat doesn't love me anymore!
#
# 80254 40723 jaccard: 0.7777777777777778; tr: 0.9936103820800781
# how to pick up a girl from auschwitz:
#  how to pick up a girl from auschwitz
#
# 80254 65740 jaccard: 1.0; tr: 0.9999997615814209
# how to pick up a girl from auschwitz:
#  how to pick up a girl from auschwitz:
#
# 80254 84395 jaccard: 0.7777777777777778; tr: 0.9936106204986572
# how to pick up a girl from auschwitz:
#  how to pick up a girl from auschwitz
#
# 35796 34678 jaccard: 1.0; tr: 1.0000001192092896
# i hate it when white people throw gang signs thinking they're black and shit
#  i hate it when white people throw gang signs thinking they're black and shit
#
# 79843 72450 jaccard: 1.0; tr: 0.9999998807907104
# the closest some of us will ever get to heaven
#  the closest some of us will ever get to heaven
#
# 16042 89461 jaccard: 1.0; tr: 0.9999999403953552
# women use chemicals to remove polish everyday and no one bats an eye i use chemicals to remove the polish and suddenly i'm the world's biggest villain!
#  women use chemicals to remove polish everyday and no one bats an eye i use chemicals to remove the polish and suddenly i'm the world's biggest villain!
#
# 31985 14836 jaccard: 1.0; tr: 1.0
# when your dad comes to career day and starts handing out mixtapes
#  when your dad comes to career day and starts handing out mixtapes
#
# 07314 28495 jaccard: 1.0; tr: 1.0
# spending alot of time with your pets
#  spending alot of time with your pets
#
# 91275 92741 jaccard: 0.75; tr: 0.983174204826355
# wait, mohammad come back!! didn't mean to laugh, really size doesn't matter to me
#  wait, mohammad come back!! i didn't mean to laugh, really size doesh't matter to me lol
#
# 91275 81365 jaccard: 0.75; tr: 0.983174204826355
# wait, mohammad come back!! didn't mean to laugh, really size doesn't matter to me
#  wait, mohammad come back!! i didn't mean to laugh, really size doesh't matter to me lol
#
# 91275 62417 jaccard: 1.0; tr: 1.0
# wait, mohammad come back!! didn't mean to laugh, really size doesn't matter to me
#  wait, mohammad come back!! didn't mean to laugh, really size doesn't matter to me
#
# 97423 74813 jaccard: 1.0; tr: 0.9999996423721313
# a little gas never killed anybody right?
#  a little gas never killed anybody right?
#
# 20974 73021 jaccard: 1.0; tr: 1.0000001192092896
# when mom asks where all the jews went
#  when mom asks where all the jews went
#
# 20974 09467 jaccard: 1.0; tr: 1.0000001192092896
# when mom asks where all the jews went
#  when mom asks where all the jews went
#
# 20974 54098 jaccard: 1.0; tr: 1.0
# when mom asks where all the jews went
#  when mom asks where all the jews went
#
# 68921 18350 jaccard: 1.0; tr: 0.9999998807907104
# when you see the gas bill
#  when you see the gas bill
#
# 68921 51403 jaccard: 1.0; tr: 0.9999998807907104
# when you see the gas bill
#  when you see the gas bill
#
# 68921 60721 jaccard: 1.0; tr: 0.9999998807907104
# when you see the gas bill
#  when you see the gas bill
#
# 10274 06243 jaccard: 1.0; tr: 0.9999998807907104
# (laughs in goat fucker)
#  (laughs in goat fucker)
#
# 45031 81075 jaccard: 1.0; tr: 1.0000001192092896
# they're not alllll rapists... right?
#  they're not alllll rapists... right?
#
# 49201 57418 jaccard: 1.0; tr: 0.9999997615814209
# 3.8 billion of them on earth. why isn't it clean yet?
#  3.8 billion of them on earth. why isn't it clean yet?
#
# 17864 39425 jaccard: 1.0; tr: 1.0000001192092896
# when dad keeps banging the goat instead of you
#  when dad keeps banging the goat instead of you
#
# 74265 43127 jaccard: 1.0; tr: 1.0000001192092896
# it's taekwondo, not taekwondon't
#  it's taekwondo, not taekwondon't
#
# 68749 48570 jaccard: 1.0; tr: 0.9999999403953552
# "my name is osama bin laden and this is jackass"
#  "my name is osama bin laden and this is jackass"
#
# 49023 26930 jaccard: 1.0; tr: 0.9999998807907104
# african american leaders organizing the la riots april 29, 1992
#  african american leaders organizing the la riots april 29, 1992
#
# 54782 94107 jaccard: 1.0; tr: 0.9999998211860657
# because even other planets need crime
#  because even other planets need crime
#
# 10234 96103 jaccard: 1.0; tr: 1.0000001192092896
# when you've decided to start a life of crime
#  when you've decided to start a life of crime
#
# 65948 05879 jaccard: 1.0; tr: 0.9999997615814209
# me watching the pride parade
#  me watching the pride parade
#
# 86173 92836 jaccard: 1.0; tr: 1.0
# when i said i wanted a little pussy this is not really what i had in mind.
#  when i said i wanted a little pussy this is not really what i had in mind.
#
# 23817 82940 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 16298 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 75209 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 89123 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 01578 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 02793 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 90175 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 10436 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 60739 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 70864 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 83056 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 75231 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys
#
# 23817 94610 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 52948 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 38057 jaccard: 1.0; tr: 1.0000001192092896
# sea monkeys
#  sea monkeys
#
# 23817 79531 jaccard: 1.0; tr: 0.9999999403953552
# sea monkeys
#  sea monkeys

# %%
meme_idxs = list(meme_idx_to_text.keys())
psuedo_text_idx_to_meme_idxs = {}
for i, j in zip(i_idxs, j_idxs):
    for k in range(len(psuedo_text_idx_to_meme_idxs)):
        if meme_idxs[i] in psuedo_text_idx_to_meme_idxs[k] or meme_idxs[j] in psuedo_text_idx_to_meme_idxs[k]:
            psuedo_text_idx_to_meme_idxs[k].update({meme_idxs[i], meme_idxs[j]})
            break
    else:
        psuedo_text_idx_to_meme_idxs[len(psuedo_text_idx_to_meme_idxs)] = {meme_idxs[i], meme_idxs[j]}
print(len(psuedo_text_idx_to_meme_idxs))
# Out:
# 1743

# %%
psuedo_text_idx_to_meme_idxs
# Out:
# {0: {'13894', '53027', '59817', '96180'},
#  1: {'70914', '97623', '98531'},
#  2: {'02973', '39785', '70426'},
#  3: {'50346', '52614', '58306'},
#  4: {'19324', '95278'},
#  5: {'73849', '79346'},
#  6: {'20497', '70146'},
#  7: {'29357', '65207', '67801', '97180'},
#  8: {'15872', '42816'},
#  9: {'29587', '72598'},
#  10: {'28396', '51846'},
#  11: {'01569', '83579'},
#  12: {'06418', '83152'},
#  13: {'13856', '18946', '86354'},
#  14: {'01936', '34217', '39625', '63548', '68730', '74386'},
#  15: {'56421', '59613', '92617'},
#  16: {'48279', '91286'},
#  17: {'27401', '36872'},
#  18: {'25473', '47859'},
#  19: {'69357', '79036'},
#  20: {'81059', '93572'},
#  21: {'52469', '67894', '74530'},
#  22: {'46127', '48976'},
#  23: {'86139', '87594'},
#  24: {'12548', '89607'},
#  25: {'29163', '70492', '90573', '92154'},
#  26: {'09867',
#   '12490',
#   '25340',
#   '28154',
#   '30598',
#   '32658',
#   '36508',
#   '46239',
#   '51462',
#   '54981',
#   '57982',
#   '72834',
#   '75291',
#   '80156',
#   '90583'},
#  27: {'38612', '48015'},
#  28: {'04397', '15803'},
#  29: {'18350', '51403', '60721', '68921'},
#  30: {'91547', '98457'},
#  31: {'38145', '82563', '93741'},
#  32: {'05384', '64708'},
#  33: {'01845', '06584'},
#  34: {'01829', '74862', '80521'},
#  35: {'34165', '36075'},
#  36: {'09617', '86714'},
#  37: {'41263', '70432', '79125', '96258'},
#  38: {'06825', '57349'},
#  39: {'01236',
#   '01348',
#   '02947',
#   '03847',
#   '05914',
#   '07463',
#   '10793',
#   '15072',
#   '17834',
#   '20568',
#   '25780',
#   '25913',
#   '27156',
#   '29013',
#   '31408',
#   '34518',
#   '34816',
#   '35097',
#   '36804',
#   '39170',
#   '48136',
#   '50624',
#   '56134',
#   '58732',
#   '64781',
#   '68231',
#   '68954',
#   '69842',
#   '70269',
#   '71368',
#   '71658',
#   '74380',
#   '81692',
#   '82169',
#   '85173',
#   '91270',
#   '91562',
#   '92180',
#   '92845',
#   '94850',
#   '95401',
#   '96078',
#   '97162',
#   '97542',
#   '98517'},
#  40: {'24567', '67125', '84269'},
#  41: {'07486', '68079'},
#  42: {'15064', '21408', '54102'},
#  43: {'63710', '64127', '68971'},
#  44: {'64385', '74391'},
#  45: {'26759', '50427'},
#  46: {'27398', '67059'},
#  47: {'18730', '73069'},
#  48: {'91754', '98461'},
#  49: {'18673', '75230', '80652', '89532'},
#  50: {'04986',
#   '09827',
#   '10693',
#   '14950',
#   '17548',
#   '30289',
#   '53249',
#   '59073',
#   '71230'},
#  51: {'09624', '28405'},
#  52: {'02431', '78351'},
#  53: {'08469', '71436', '76532'},
#  54: {'20654', '20736', '51763'},
#  55: {'34901', '50293'},
#  56: {'19230', '28793'},
#  57: {'05172', '93685'},
#  58: {'60578', '98501'},
#  59: {'14083', '37184', '40216', '43612', '51726', '79612', '85461', '94580'},
#  60: {'15480', '45987'},
#  61: {'51903', '81069'},
#  62: {'31290', '72584'},
#  63: {'06873', '84502'},
#  64: {'06359', '30486', '87934', '97501'},
#  65: {'45016', '76250'},
#  66: {'23198', '27861', '61952', '62589'},
#  67: {'80269', '98416'},
#  68: {'05712', '57120'},
#  69: {'10259', '18597', '35219'},
#  70: {'09364', '43716', '90146'},
#  71: {'21547', '32915', '51278', '71058'},
#  72: {'16048', '65213'},
#  73: {'31029', '58426'},
#  74: {'52947', '96785'},
#  75: {'05869', '93826'},
#  76: {'43608', '84072'},
#  77: {'17932', '91708'},
#  78: {'09814', '86491'},
#  79: {'38209', '81734'},
#  80: {'08275', '80247'},
#  81: {'19406', '50793'},
#  82: {'13857', '24980', '62904'},
#  83: {'21047', '38912', '43617', '76815'},
#  84: {'10659', '29036', '47309'},
#  85: {'49083', '51397', '82697'},
#  86: {'05916', '45938'},
#  87: {'23961', '67823'},
#  88: {'05269', '54692', '76489', '79286'},
#  89: {'06458', '16097', '25983'},
#  90: {'31684',
#   '40965',
#   '45601',
#   '46730',
#   '46978',
#   '71364',
#   '83914',
#   '86041',
#   '93165',
#   '94823'},
#  91: {'17450', '26794'},
#  92: {'10748', '91268'},
#  93: {'02763', '36190', '42179', '53147', '70153'},
#  94: {'49621', '53692', '62417', '69548', '81365', '91275', '92741'},
#  95: {'18407', '65240'},
#  96: {'10264', '52904', '67130', '70652', '92143'},
#  97: {'17832', '38054'},
#  98: {'15432', '19670', '27659', '50679'},
#  99: {'31794', '34721'},
#  100: {'17205', '78214'},
#  101: {'09176', '15649'},
#  102: {'51460', '85936'},
#  103: {'23807', '71294', '79315'},
#  104: {'03241', '32615', '63520'},
#  105: {'03871', '38041', '69041'},
#  106: {'25781', '34079', '36974', '82179'},
#  107: {'34186', '81546'},
#  108: {'01653', '48703', '61037'},
#  109: {'17469', '42319', '45608', '76510'},
#  110: {'51928', '61234'},
#  111: {'49630', '71950'},
#  112: {'60173', '71826'},
#  113: {'09486', '68423', '84527'},
#  114: {'39652', '40967'},
#  115: {'13986',
#   '15478',
#   '21637',
#   '49387',
#   '53108',
#   '54713',
#   '68342',
#   '70435',
#   '72461',
#   '95078',
#   '98345'},
#  116: {'08654', '65908'},
#  117: {'26905', '80361'},
#  118: {'15283', '21849'},
#  119: {'31268', '96153'},
#  120: {'63917', '67842', '81409'},
#  121: {'51037', '80237'},
#  122: {'67084', '92085'},
#  123: {'26043', '36058', '72810'},
#  124: {'26031', '43519'},
#  125: {'64701', '79385'},
#  126: {'12063', '26495', '48970', '87693'},
#  127: {'14087', '37815', '56972'},
#  128: {'10827', '64078'},
#  129: {'50273', '52407', '79451'},
#  130: {'25397', '71539'},
#  131: {'14267', '46058'},
#  132: {'06218', '69804'},
#  133: {'16075', '64027', '91027'},
#  134: {'20751', '69428'},
#  135: {'27489', '29056', '51694'},
#  136: {'40721', '81394'},
#  137: {'67835', '68042'},
#  138: {'41832', '70549'},
#  139: {'57203', '68379'},
#  140: {'74235', '75239'},
#  141: {'37621', '63275', '78642'},
#  142: {'43201', '58649'},
#  143: {'76213', '87695'},
#  144: {'03251', '07248'},
#  145: {'04651', '60794'},
#  146: {'07385', '12649', '13849', '16490', '27391', '42690', '47096', '64320'},
#  147: {'13269',
#   '18764',
#   '19540',
#   '41372',
#   '47826',
#   '48512',
#   '60937',
#   '74158',
#   '80243',
#   '86217'},
#  148: {'43725', '61927'},
#  149: {'23570', '56389'},
#  150: {'67198', '68472'},
#  151: {'09347', '31058'},
#  152: {'20183', '30849', '36472', '51687'},
#  153: {'05614', '54761'},
#  154: {'42387', '56741'},
#  155: {'67415', '90483'},
#  156: {'20485', '86054', '95843'},
#  157: {'26347', '72531'},
#  158: {'20196', '75403'},
#  159: {'06412', '38245'},
#  160: {'45283', '46712', '58197', '67394', '93512'},
#  161: {'37859', '92185'},
#  162: {'75481', '90564'},
#  163: {'28971', '50873'},
#  164: {'02735',
#   '03145',
#   '20356',
#   '26315',
#   '28957',
#   '29703',
#   '40286',
#   '49165',
#   '49685',
#   '60839',
#   '72514',
#   '74631',
#   '78469',
#   '79463',
#   '84097'},
#  165: {'08395', '14695'},
#  166: {'21693', '23415', '59837'},
#  167: {'14697', '81079'},
#  168: {'65342', '68194'},
#  169: {'32468', '54389'},
#  170: {'01524', '03642', '07481', '50137', '60982', '83175'},
#  171: {'17390', '83492'},
#  172: {'06194', '08674', '89140', '94617'},
#  173: {'61028', '65320'},
#  174: {'25497', '76034'},
#  175: {'54632', '69137'},
#  176: {'06875', '17208', '38495', '90165'},
#  177: {'78405', '78906'},
#  178: {'41258', '96172'},
#  179: {'37965', '56841'},
#  180: {'21869', '53278'},
#  181: {'40865', '83415', '95683'},
#  182: {'59186', '85271'},
#  183: {'21453', '52304', '85421', '90648'},
#  184: {'13482', '46507', '61802', '78064'},
#  185: {'50689', '51734'},
#  186: {'43910', '73562'},
#  187: {'15743', '80792'},
#  188: {'06579', '60128', '76421', '95821'},
#  189: {'17539', '25639', '26947', '63295'},
#  190: {'52738', '68270'},
#  191: {'47598', '68309'},
#  192: {'10256', '82763'},
#  193: {'20759', '24810', '84537'},
#  194: {'15647', '76328'},
#  195: {'20879', '56940', '75138', '81760'},
#  196: {'01498', '07591'},
#  197: {'18935', '41835', '85923'},
#  198: {'36590', '45912', '78260'},
#  199: {'31074', '40693'},
#  200: {'12349', '38962', '90365'},
#  201: {'15409', '26183', '63129'},
#  202: {'27139', '96235'},
#  203: {'93861', '98561'},
#  204: {'07319', '30695', '47196', '60789', '81953', '92467'},
#  205: {'09138',
#   '13470',
#   '20681',
#   '23501',
#   '34970',
#   '38514',
#   '46501',
#   '46918',
#   '47386',
#   '73204',
#   '76519',
#   '78294',
#   '81540',
#   '82539'},
#  206: {'32608', '40728', '58604', '69043', '91740'},
#  207: {'86024', '92453'},
#  208: {'21746', '82379', '97842'},
#  209: {'02169', '78124'},
#  210: {'35642', '37548'},
#  211: {'23467', '27816', '45307', '49856', '61793', '80576', '91730'},
#  212: {'03957', '24019'},
#  213: {'18693', '84276'},
#  214: {'16047', '72893'},
#  215: {'05241',
#   '10574',
#   '14893',
#   '16832',
#   '25971',
#   '43085',
#   '46359',
#   '59231',
#   '65730',
#   '70213'},
#  216: {'17938', '54976'},
#  217: {'20931', '23459', '36480'},
#  218: {'06914', '63124', '75832', '87519', '94087'},
#  219: {'13960', '46920', '91283'},
#  220: {'07521', '95108'},
#  221: {'38094', '41962', '45706'},
#  222: {'39821', '47865'},
#  223: {'41923', '67953'},
#  224: {'21780', '41680', '62314', '64015', '85690', '97815'},
#  225: {'29376', '64913', '91058'},
#  226: {'13620', '42317'},
#  227: {'45806', '47209', '53064', '75928'},
#  228: {'42638', '92867'},
#  229: {'21354', '67183'},
#  230: {'52974', '53678', '73841', '85912'},
#  231: {'05984',
#   '06823',
#   '13764',
#   '17963',
#   '29813',
#   '37140',
#   '46509',
#   '79865',
#   '94571',
#   '98103',
#   '98724'},
#  232: {'09184',
#   '19834',
#   '24851',
#   '36497',
#   '37295',
#   '52078',
#   '65328',
#   '70284',
#   '85291',
#   '94360'},
#  233: {'20835', '39541', '40871', '59732', '76321', '79568', '83957'},
#  234: {'59684', '86170'},
#  235: {'06489',
#   '07239',
#   '08317',
#   '16734',
#   '27965',
#   '28610',
#   '46721',
#   '51032',
#   '59128',
#   '59376',
#   '74350',
#   '92643',
#   '97315'},
#  236: {'02831',
#   '13528',
#   '14976',
#   '27058',
#   '65741',
#   '73045',
#   '75021',
#   '98245',
#   '98601'},
#  237: {'05826', '67984'},
#  238: {'30958', '87209'},
#  239: {'13506', '35218'},
#  240: {'05968', '09324', '25463', '40329', '43569', '96840'},
#  241: {'04356',
#   '13520',
#   '15920',
#   '19247',
#   '23854',
#   '38547',
#   '40573',
#   '50491',
#   '67029',
#   '67129',
#   '69873',
#   '75203',
#   '87610'},
#  242: {'03574', '05214'},
#  243: {'47189', '92514'},
#  244: {'05841', '37054'},
#  245: {'03841', '20943', '26489', '34862', '35970', '38419', '48760'},
#  246: {'31568', '42087', '47098', '96301'},
#  247: {'64017', '69520'},
#  248: {'37980', '63871'},
#  249: {'18594', '20876', '36248'},
#  250: {'65124', '94876'},
#  251: {'04798', '16082'},
#  252: {'01865', '93275'},
#  253: {'32015', '48103', '52479', '81975', '98026'},
#  254: {'43198', '85729'},
#  255: {'69158', '72160'},
#  256: {'27436', '95482'},
#  257: {'12807', '20617', '21604', '41589', '43728', '46953', '56081', '70356'},
#  258: {'16058', '34652'},
#  259: {'70849', '83954'},
#  260: {'10463', '48062', '90786'},
#  261: {'40137', '82749'},
#  262: {'28735', '38069'},
#  263: {'14573', '30412'},
#  264: {'21038', '31786', '37901', '59470', '72486', '80513', '81054', '97035'},
#  265: {'20567', '74602'},
#  266: {'14958', '93650'},
#  267: {'08937', '78459', '78960', '95742'},
#  268: {'18254', '93410'},
#  269: {'54286', '62035'},
#  270: {'01564', '89407', '97023'},
#  271: {'02987', '38624', '57923', '92876'},
#  272: {'36187', '72094'},
#  273: {'28049', '47095'},
#  274: {'10527', '36204'},
#  275: {'19526', '26319', '57043', '62197'},
#  276: {'75068', '85413'},
#  277: {'15983', '65237'},
#  278: {'13769', '40315', '49106', '82346'},
#  279: {'63028', '90278'},
#  280: {'01642', '28935', '36048', '80967', '97160'},
#  281: {'16283', '67021'},
#  282: {'37186', '69342'},
#  283: {'01598', '71392', '72604'},
#  284: {'50461', '58640'},
#  285: {'30185', '37182', '37902', '71480', '82460'},
#  286: {'17345', '48920', '59342'},
#  287: {'03285', '59261', '80347'},
#  288: {'31760', '89170'},
#  289: {'30276', '74890'},
#  290: {'02576', '80764', '92081'},
#  291: {'18275', '21589', '28637'},
#  292: {'08451', '27038', '67435', '82154', '90673'},
#  293: {'14276', '45780'},
#  294: {'58301', '62805'},
#  295: {'24039', '86907'},
#  296: {'06897', '50473'},
#  297: {'13964', '20873', '70189'},
#  930: {'08163', '36185', '57962', '75360', '79182'},
#  931: {'39576', '53096'},
#  932: {'05127', '91234'},
#  933: {'27948', '78095'},
#  934: {'79085', '93506'},
#  935: {'06127', '20371'},
#  936: {'03275', '86250'},
#  937: {'69250', '93087'},
#  938: {'21950', '39624'},
#  939: {'05784', '52301'},
#  940: {'27385', '97845'},
#  941: {'01548', '45603'},
#  942: {'49032', '53901'},
#  943: {'52971', '94501'},
#  944: {'56921', '71680'},
#  945: {'32168', '36089', '52379', '57631', '69380', '73982'},
#  946: {'34619', '74563'},
#  947: {'08375', '96407'},
#  948: {'46753', '94870'},
#  949: {'38029', '52710'},
#  950: {'59143', '78923'},
#  951: {'40651', '47591', '60759'},
#  952: {'69035', '91683'},
#  953: {'21348', '49701', '59140', '59327'},
#  954: {'18507', '56948'},
#  955: {'16538', '64029'},
#  956: {'10734', '49671'},
#  957: {'21598', '43817'},
#  958: {'13548', '28641'},
#  959: {'37642', '64287'},
#  960: {'61825', '63104'},
#  961: {'14602', '84709'},
#  962: {'07389', '28759', '32897'},
#  963: {'20718', '34152', '63924'},
#  964: {'27856', '36571'},
#  965: {'25197', '91457'},
#  966: {'35924', '82413'},
#  967: {'30168', '97258'},
#  968: {'02674', '78205'},
#  969: {'14072', '25683'},
#  970: {'07268', '43178'},
#  971: {'72145', '78936'},
#  972: {'20184', '86947'},
#  973: {'16389', '57132'},
#  974: {'09124', '28391'},
#  975: {'04321', '15839', '17459'},
#  976: {'58134', '74956'},
#  977: {'16492', '83271'},
#  978: {'35780', '49802', '85369'},
#  979: {'10478', '41890'},
#  980: {'42801', '86391'},
#  981: {'41908', '87564'},
#  982: {'38641', '51802'},
#  983: {'17425', '20513', '25716'},
#  984: {'08567', '38046', '90143'},
#  985: {'68950', '69057', '87621'},
#  986: {'62510', '65478'},
#  987: {'17052', '85793'},
#  988: {'29841', '78219'},
#  989: {'16948', '89741'},
#  990: {'12389', '49285'},
#  991: {'10689', '60985'},
#  992: {'21609', '71530'},
#  993: {'60541', '83946'},
#  994: {'29075', '75241'},
#  995: {'31627', '67190'},
#  996: {'68407', '79234', '85172', '90463'},
#  997: {'09387', '67048'},
#  998: {'08196', '89076'},
#  999: {'05329', '62134'},
#  ...}

# %%
meme_idx_to_psuedo_text_idx = {}
for psuedo_text_idx, meme_idxs in psuedo_text_idx_to_meme_idxs.items():
    for meme_idx in meme_idxs:
        meme_idx_to_psuedo_text_idx[meme_idx] = psuedo_text_idx
print(len(meme_idx_to_psuedo_text_idx))

# for meme idxs that are not covered
non_covered_meme_idxs = set(df['id'].values) - set(meme_idx_to_psuedo_text_idx.keys())
for i, non_covered_meme_idx in enumerate(non_covered_meme_idxs, start=len(psuedo_text_idx_to_meme_idxs)):
    meme_idx_to_psuedo_text_idx[non_covered_meme_idx] = i
print(len(meme_idx_to_psuedo_text_idx))
# Out:
# 4244
# 10000

# %%
df['pseudo_text_idx'] = df['id'].map(meme_idx_to_psuedo_text_idx)

# %%
df.describe()
# Out:
#               label      text_idx  pseudo_text_idx
# count  10000.000000  10000.000000     10000.000000
# mean       0.375600   3808.343200      2996.132300
# std        0.484302   2370.330576      2297.623341
# min        0.000000      0.000000         0.000000
# 25%        0.000000   1685.750000       920.000000
# 50%        0.000000   3681.500000      2498.500000
# 75%        1.000000   5843.250000      4998.250000
# max        1.000000   8044.000000      7498.000000

# %%
df.head()
# Out:
#           id            img  label  \
# 42953  42953  img/42953.png      0
# 23058  23058  img/23058.png      0
# 13894  13894  img/13894.png      0
# 37408  37408  img/37408.png      0
# 82403  82403  img/82403.png      0
#
#                                                     text  split  text_idx  \
# 42953   its their character not their color that matters  train         0
# 23058  don't be afraid to love again everyone is not ...  train         1
# 13894                           putting bows on your pet  train         2
# 37408  i love everything and everybody! except for sq...  train         3
# 82403  everybody loves chocolate chip cookies, even h...  train         4
#
#        pseudo_text_idx
# 42953             5484
# 23058             2036
# 13894                0
# 37408             3216
# 82403             2244

# %% [markdown]
# # Find Image index

# %%
from skimage.metrics import structural_similarity as compare_ssim
import imutils
import cv2

# %%
#imgs = [cv2.resize(cv2.imread(f'{data_dir}/{img_fp}', 0), (128, 128)) for img_fp in df['img'].values]
#len(imgs)

# %%
#plt.imshow(imgs[2], cmap='gray')

# %%
# scores_ssim = np.zeros((len(imgs), len(imgs)))
# for i in tqdm(range(len(imgs))):
#     for j in range(i+1, len(imgs)):
#         (score, diff) = compare_ssim(imgs[i], imgs[j], full=True)
#         scores_ssim[i, j] = score

# %%
import torch
from torchvision.models import resnet18 

model = resnet18(pretrained=True)
model.eval()
feature_extractor = torch.nn.Sequential(*list(model.children())[:-1])
x = torch.randn([1,3,224,224])
output = feature_extractor(x) 
print(output.shape)
# Out:
# torch.Size([1, 512, 1, 1])
# /home/gokul_kumar/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
from PIL import Image
import torchvision.transforms as T

transforms = T.Compose([T.Resize(224), T.ToTensor(), T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

imgs = []
for img_fp in tqdm(df['img'].values.tolist()):
    img = Image.open(f'{data_dir}/{img_fp}').convert('RGB').resize((224, 224))
    img = transforms(img).unsqueeze(dim=0)
    imgs.append(img)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
imgs = torch.cat(imgs, dim=0)
print(imgs.shape)
# Out:
# torch.Size([10000, 3, 224, 224])

# %%
batch_size = 100
assert len(imgs) % batch_size == 0
num_batches = len(imgs) // batch_size
imgs_features = []
for i in tqdm(range(num_batches)):
    start_idx = i*batch_size
    end_idx = start_idx + batch_size
    imgs_features_batch = feature_extractor(imgs[start_idx:end_idx])
    imgs_features_batch = imgs_features_batch.squeeze().detach().numpy()
    imgs_features.append(imgs_features_batch)
imgs_features = np.concatenate(imgs_features)
print(imgs_features.shape)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# (10000, 512)

# %%
from sklearn.metrics.pairwise import cosine_distances, cosine_similarity
scores_img = cosine_similarity(imgs_features)
for i in range(len(scores_img)):
    scores_img[i, i] = 0
print(scores_img.shape)
print(scores_img.min(), scores_img.max())
# Out:
# (10000, 10000)
# 0.0 0.99947596

# %%
i_idxs, j_idxs = np.where((scores_img>0.92) & (scores_img<1))
print(len(i_idxs))
meme_idx_to_img = df['img'].to_dict()
meme_idxs = list(meme_idx_to_img.keys())
for i, j in zip(i_idxs[:3], j_idxs[:3]):
    print(meme_idxs[i], meme_idxs[j],  f'scores_img: {scores_img[i, j]}')
    fig, axes = plt.subplots(1, 2)
    axes[0].imshow(Image.open(f'{data_dir}/{meme_idx_to_img[meme_idxs[i]]}'))
    axes[1].imshow(Image.open(f'{data_dir}/{meme_idx_to_img[meme_idxs[j]]}'))
    plt.show()
# Out:
# 14556
# 42953 51683 scores_img: 0.9826446771621704
# 82403 71038 scores_img: 0.923524022102356
# 16952 92738 scores_img: 0.94631427526474

# %%
meme_idxs = list(meme_idx_to_img.keys())
psuedo_img_idx_to_meme_idxs = {}
for i, j in zip(i_idxs, j_idxs):
    for k in range(len(psuedo_img_idx_to_meme_idxs)):
        if meme_idxs[i] in psuedo_img_idx_to_meme_idxs[k] or meme_idxs[j] in psuedo_img_idx_to_meme_idxs[k]:
            psuedo_img_idx_to_meme_idxs[k].update({meme_idxs[i], meme_idxs[j]})
            break
    else:
        psuedo_img_idx_to_meme_idxs[len(psuedo_img_idx_to_meme_idxs)] = {meme_idxs[i], meme_idxs[j]}
print(len(psuedo_img_idx_to_meme_idxs))
# Out:
# 1641

# %%
psuedo_img_idx_to_meme_idxs
# Out:
# {0: {'42953', '51683'},
#  1: {'71038', '82403'},
#  2: {'16952', '92738'},
#  3: {'28563', '76932'},
#  4: {'01247',
#   '03789',
#   '03854',
#   '03896',
#   '09251',
#   '17352',
#   '21647',
#   '26184',
#   '26419',
#   '27864',
#   '29708',
#   '31794',
#   '32716',
#   '34207',
#   '35160',
#   '35210',
#   '36924',
#   '42690',
#   '48250',
#   '48276',
#   '50176',
#   '50327',
#   '51403',
#   '54376',
#   '57284',
#   '59340',
#   '59402',
#   '61423',
#   '62198',
#   '63915',
#   '67983',
#   '71086',
#   '71532',
#   '72380',
#   '72413',
#   '75941',
#   '79351',
#   '80534',
#   '81943',
#   '83456',
#   '86021',
#   '87390',
#   '91768',
#   '92547',
#   '93208',
#   '94302',
#   '94723',
#   '97068',
#   '97623',
#   '98416',
#   '98531'},
#  5: {'73849', '79346'},
#  6: {'09352', '13426'},
#  7: {'02143',
#   '03624',
#   '03764',
#   '13852',
#   '14238',
#   '15480',
#   '17802',
#   '19074',
#   '20749',
#   '25748',
#   '41802',
#   '45938',
#   '45987',
#   '50312',
#   '57029',
#   '57918',
#   '58497',
#   '69815',
#   '78465',
#   '84563',
#   '86307',
#   '86974',
#   '91065',
#   '91208',
#   '91803',
#   '94638',
#   '96857'},
#  8: {'28936', '52036'},
#  9: {'28061', '97213'},
#  10: {'43279', '49752'},
#  11: {'25610', '42856', '75892'},
#  12: {'15872', '53064'},
#  13: {'50961', '64318'},
#  14: {'10743', '67350'},
#  15: {'25719', '48971'},
#  16: {'12967', '76825'},
#  17: {'06531',
#   '14765',
#   '38475',
#   '41573',
#   '43078',
#   '52617',
#   '56891',
#   '58029',
#   '59012',
#   '96541'},
#  18: {'53241', '60794', '95812'},
#  19: {'53976', '94130'},
#  20: {'05389',
#   '06231',
#   '07286',
#   '15049',
#   '28315',
#   '38217',
#   '42810',
#   '42897',
#   '42970',
#   '43025',
#   '48379',
#   '50398',
#   '51693',
#   '67938',
#   '70193',
#   '72891',
#   '72903',
#   '83607',
#   '84379',
#   '89762',
#   '97583'},
#  21: {'04876', '43569', '74913', '96840'},
#  22: {'92075', '95403'},
#  23: {'13675', '58371'},
#  24: {'08295', '52379', '57631', '57814'},
#  25: {'25483', '69357'},
#  26: {'42137', '48396'},
#  27: {'02476', '34972'},
#  28: {'31294',
#   '35062',
#   '56432',
#   '58210',
#   '60197',
#   '64825',
#   '86145',
#   '87543',
#   '90128'},
#  29: {'60147', '83946'},
#  30: {'06243',
#   '10725',
#   '21869',
#   '36508',
#   '37692',
#   '39067',
#   '46239',
#   '51462',
#   '54981',
#   '57169',
#   '75291',
#   '90583'},
#  31: {'38612', '48015'},
#  32: {'38465', '51802', '64513', '67254', '70426'},
#  33: {'53289', '71430'},
#  34: {'03947', '05917', '30247'},
#  35: {'01492', '28396', '38145', '93741'},
#  36: {'02841',
#   '05462',
#   '06425',
#   '07291',
#   '09765',
#   '12957',
#   '13495',
#   '14026',
#   '16097',
#   '19736',
#   '20395',
#   '23059',
#   '24390',
#   '25983',
#   '31687',
#   '35628',
#   '36240',
#   '38105',
#   '39478',
#   '39741',
#   '42398',
#   '42896',
#   '42936',
#   '43217',
#   '47521',
#   '49076',
#   '49176',
#   '51243',
#   '51283',
#   '52960',
#   '56374',
#   '56389',
#   '61208',
#   '61973',
#   '65380',
#   '69250',
#   '70264',
#   '72689',
#   '76450',
#   '79832',
#   '85741',
#   '87596',
#   '94620',
#   '98256'},
#  37: {'34015', '34791'},
#  38: {'17953', '41385'},
#  39: {'35618', '43608'},
#  40: {'67953', '78409', '94721'},
#  41: {'01236',
#   '01348',
#   '02947',
#   '03847',
#   '05914',
#   '07463',
#   '10793',
#   '15072',
#   '17834',
#   '20568',
#   '25780',
#   '25913',
#   '27156',
#   '29013',
#   '31408',
#   '34518',
#   '34816',
#   '35097',
#   '36804',
#   '39170',
#   '50624',
#   '56134',
#   '58732',
#   '64781',
#   '68231',
#   '68954',
#   '69842',
#   '70269',
#   '71368',
#   '71658',
#   '74380',
#   '82169',
#   '85173',
#   '91270',
#   '91562',
#   '92180',
#   '92845',
#   '94850',
#   '95401',
#   '96078',
#   '97162',
#   '97542',
#   '98517'},
#  42: {'24567', '84269'},
#  43: {'08175',
#   '08546',
#   '12890',
#   '20951',
#   '30561',
#   '37502',
#   '39201',
#   '67034',
#   '71320',
#   '76239',
#   '89764'},
#  44: {'14625', '54102', '68431', '92413'},
#  45: {'05297',
#   '07915',
#   '10238',
#   '30687',
#   '38051',
#   '46027',
#   '46279',
#   '57183',
#   '63217',
#   '81970'},
#  46: {'02568', '03271'},
#  47: {'12348', '17425', '18307'},
#  48: {'13865', '39420', '70532'},
#  49: {'17093', '20685', '24083', '25806', '70623', '76419'},
#  50: {'36450', '91754'},
#  51: {'59410', '97523'},
#  52: {'14950', '17548', '30289', '53249', '57890', '59073', '96381'},
#  53: {'84236', '92670'},
#  54: {'16097',
#   '19526',
#   '19736',
#   '24390',
#   '25983',
#   '28765',
#   '35628',
#   '42398',
#   '43217',
#   '49176',
#   '51283',
#   '53941',
#   '56389',
#   '61208',
#   '61379',
#   '61973',
#   '69250',
#   '72689',
#   '78351',
#   '98256'},
#  55: {'48917', '79856'},
#  56: {'04732', '71436', '76532'},
#  57: {'20654', '20736'},
#  58: {'13769', '30859', '49106', '50487', '67354', '71845', '75614'},
#  59: {'06431', '19238', '50462'},
#  60: {'05172', '71259'},
#  61: {'18362', '81673'},
#  62: {'02816', '48635', '67593', '74509', '85426'},
#  63: {'41830', '67842'},
#  64: {'15983', '34708', '93260'},
#  65: {'40839', '76581'},
#  66: {'53068', '76250'},
#  67: {'80269', '83206'},
#  68: {'04591',
#   '12039',
#   '23795',
#   '23897',
#   '26950',
#   '32691',
#   '54682',
#   '60329',
#   '68349',
#   '69017',
#   '72941',
#   '79864',
#   '81296',
#   '83920',
#   '86730'},
#  69: {'05948', '21853'},
#  70: {'01765', '10259', '30291', '35219', '45120', '61485'},
#  71: {'09364', '90146'},
#  72: {'02657', '63095', '79815', '96183'},
#  73: {'43721', '56871'},
#  74: {'19352', '96235'},
#  75: {'20956', '24368', '39815', '45167', '65378', '82461'},
#  76: {'31029', '35460', '58426', '63185'},
#  77: {'40567', '70435'},
#  78: {'07895', '25368', '62483'},
#  79: {'05869', '93826'},
#  80: {'72810', '93147'},
#  81: {'65843', '83745', '92874'},
#  82: {'27946', '45320', '56294'},
#  83: {'02691', '09385'},
#  84: {'10829', '25783'},
#  85: {'16098', '25103'},
#  86: {'13902', '92608'},
#  87: {'03971', '56287'},
#  88: {'38912', '81579'},
#  89: {'15479',
#   '49601',
#   '56082',
#   '60982',
#   '61289',
#   '63702',
#   '82697',
#   '83175',
#   '90278',
#   '90614'},
#  90: {'39256', '57932', '75082'},
#  91: {'58061', '98362'},
#  92: {'24309', '27861'},
#  93: {'05269', '23841', '71486'},
#  94: {'59287', '81675'},
#  95: {'38629', '75068'},
#  96: {'45601', '71364'},
#  97: {'06985', '91268'},
#  98: {'02763', '24051', '36190', '42179', '53147'},
#  99: {'07968', '08395', '14695'},
#  100: {'54790', '73164'},
#  101: {'16850', '23760', '28049', '28905', '47095', '51736', '90753', '92160'},
#  102: {'18407', '73690'},
#  103: {'47326', '48751'},
#  104: {'17832', '32781'},
#  105: {'30492', '35970', '38419', '48760', '61483'},
#  106: {'61578', '87695'},
#  107: {'23907', '24958', '31479', '36781', '45207', '78913'},
#  108: {'17205', '82156'},
#  109: {'02974', '15649'},
#  110: {'19860', '51460', '59143', '78539'},
#  111: {'30185', '30961', '58276', '82460'},
#  112: {'09514', '37865', '83074'},
#  113: {'02481', '75432'},
#  114: {'48703', '61037'},
#  115: {'09765', '10857', '21035', '52316', '52978', '76923', '81706'},
#  116: {'42319', '45608'},
#  117: {'02139', '04928'},
#  118: {'04278', '52746'},
#  119: {'26305', '78564'},
#  120: {'03246', '20538'},
#  121: {'09765', '21035', '39652', '76923'},
#  122: {'08654', '50931'},
#  123: {'02157',
#   '19643',
#   '25901',
#   '30249',
#   '37402',
#   '49061',
#   '50361',
#   '69074',
#   '81390'},
#  124: {'08597',
#   '09374',
#   '10584',
#   '13248',
#   '14856',
#   '15208',
#   '25438',
#   '26795',
#   '27810',
#   '31024',
#   '35692',
#   '35894',
#   '40385',
#   '62043',
#   '64709',
#   '67193',
#   '72946',
#   '74053',
#   '75023',
#   '80217',
#   '83704',
#   '86741',
#   '91526',
#   '92637',
#   '98751'},
#  125: {'08531', '60317', '61382'},
#  126: {'14958', '34805'},
#  127: {'03164', '59304', '70196', '74536', '95371'},
#  128: {'30948', '38546', '92016'},
#  129: {'21653', '79054'},
#  130: {'72386', '76354'},
#  131: {'20617', '70356', '71045', '80539'},
#  132: {'04263', '47698', '71846', '92041'},
#  133: {'26043', '50817'},
#  134: {'35628', '42509', '61379', '64701', '65094'},
#  135: {'25693', '26495', '87693'},
#  136: {'41832', '81963'},
#  137: {'14087', '56972'},
#  138: {'83127', '94178'},
#  139: {'25397', '98426'},
#  140: {'31684', '40965', '94823'},
#  141: {'20751', '64027', '69410', '72964'},
#  142: {'27489', '51694'},
#  143: {'19075', '19536', '37819', '71906', '74091', '92140'},
#  144: {'20184', '81265'},
#  145: {'40153', '85167', '92851'},
#  146: {'36805', '48612'},
#  147: {'27430', '39470'},
#  148: {'13859', '76140'},
#  149: {'16054', '16380', '19384', '34671'},
#  150: {'71249', '96284'},
#  151: {'40375', '93216'},
#  152: {'19587', '53962'},
#  153: {'03251', '35729'},
#  154: {'09132', '92750'},
#  155: {'21547', '29308', '54973', '71058', '79104', '95680'},
#  156: {'52469', '64805'},
#  157: {'49157', '92450'},
#  158: {'39148', '67198', '81467'},
#  159: {'05832',
#   '10528',
#   '16830',
#   '21780',
#   '28704',
#   '29380',
#   '36741',
#   '48792',
#   '60539',
#   '62314',
#   '64015',
#   '64025',
#   '71530',
#   '85690',
#   '86417',
#   '89536',
#   '90243',
#   '97815'},
#  160: {'62805', '89160'},
#  161: {'28954', '93658'},
#  162: {'32046', '36029'},
#  163: {'04568', '50764'},
#  164: {'42786', '60398', '93610'},
#  165: {'38047', '42309', '79286'},
#  166: {'04253', '09624', '36870', '65703'},
#  167: {'26741', '29463', '64705', '69057', '71398', '87621'},
#  168: {'40286', '49165'},
#  169: {'21693', '59837'},
#  170: {'27514', '54397', '69085'},
#  171: {'01524', '97503'},
#  172: {'06194', '94617'},
#  173: {'04326', '09561'},
#  174: {'37641', '74609'},
#  175: {'10274', '53278'},
#  176: {'46918', '59186', '85271'},
#  177: {'16409', '46357'},
#  178: {'17504', '21047'},
#  179: {'61802', '78064', '79140', '83461'},
#  180: {'09843',
#   '09867',
#   '16297',
#   '21059',
#   '26410',
#   '30598',
#   '41362',
#   '51029',
#   '53714',
#   '67059',
#   '92683',
#   '96873'},
#  181: {'69752', '79358', '98670'},
#  182: {'34920', '82946'},
#  183: {'63415', '69405'},
#  184: {'70932', '75821', '87160', '89603'},
#  336: {'12704', '13607'},
#  337: {'07451', '38402', '64839', '67924'},
#  338: {'19705', '96471'},
#  339: {'43152', '64059'},
#  340: {'13460', '86479'},
#  341: {'17354', '96402'},
#  342: {'53194', '82635'},
#  343: {'84531', '85967'},
#  344: {'36814', '92501'},
#  345: {'31527', '96172'},
#  346: {'48679', '93740'},
#  347: {'15638', '35620'},
#  348: {'02358',
#   '02946',
#   '05198',
#   '06547',
#   '07893',
#   '08476',
#   '13986',
#   '17904',
#   '25709',
#   '27915',
#   '28479',
#   '32640',
#   '35802',
#   '36954',
#   '38954',
#   '48162',
#   '51804',
#   '56231',
#   '68342',
#   '78239',
#   '82657',
#   '86543',
#   '90657',
#   '98653'},
#  349: {'65178', '91753'},
#  350: {'26087', '32564', '65809', '68749', '78052'},
#  351: {'02831', '65741', '79623'},
#  352: {'04759', '23908', '51924', '63547', '75910', '90162'},
#  353: {'56843', '81207'},
#  354: {'73198', '78923', '83052'},
#  355: {'54069', '62745'},
#  356: {'31487', '98241'},
#  357: {'34795', '84276'},
#  358: {'36107', '92148'},
#  359: {'45172', '50137', '80365', '84295'},
#  360: {'51237', '86753'},
#  361: {'01746', '86075'},
#  362: {'30816', '31924'},
#  363: {'75362', '89521'},
#  364: {'46529', '63981', '65147', '83504', '95846'},
#  365: {'85291', '94836'},
#  366: {'16845', '63805'},
#  367: {'35402', '64390'},
#  368: {'72634', '74513'},
#  369: {'25197', '69348'},
#  370: {'47901', '67183'},
#  371: {'03418', '10254', '17052', '24395', '45037'},
#  372: {'08261', '34190', '36985', '57120', '58130', '75680'},
#  373: {'36478', '89761'},
#  374: {'82346', '97184'},
#  375: {'17843', '57348'},
#  376: {'32674', '95376'},
#  377: {'30549', '35869'},
#  378: {'70842', '71046'},
#  379: {'31450', '48567'},
#  380: {'75096', '80152'},
#  381: {'51972', '52803'},
#  382: {'31729', '69178', '89437'},
#  383: {'16849', '96152'},
#  384: {'24501', '62531'},
#  385: {'10345', '38495', '43952'},
#  386: {'06412', '62147'},
#  387: {'27365', '39241', '57193', '72361', '93085'},
#  388: {'08569', '17938'},
#  389: {'27950', '47053'},
#  390: {'14823', '42715'},
#  391: {'48271', '61458', '64207', '70231'},
#  392: {'04912', '32985'},
#  393: {'32017', '34910'},
#  394: {'19472', '86457'},
#  395: {'15489', '67031'},
#  396: {'67810', '92457'},
#  397: {'13269',
#   '16783',
#   '21548',
#   '41372',
#   '42739',
#   '45610',
#   '47826',
#   '56834',
#   '86217',
#   '98463'},
#  398: {'21497', '46817'},
#  399: {'45301', '84516'},
#  400: {'58370', '96470'},
#  401: {'36420', '86201'},
#  402: {'79658', '81976'},
#  403: {'43258', '76348', '93572'},
#  404: {'14802', '16532', '26095', '49607', '75430'},
#  405: {'21405', '59436'},
#  406: {'36751', '39061', '59043'},
#  407: {'21605', '34582', '43956', '46270'},
#  408: {'39540', '81946'},
#  409: {'64531', '95306'},
#  410: {'42156', '63491'},
#  411: {'35786', '71348'},
#  412: {'54728', '65403'},
#  413: {'04976', '72968'},
#  679: {'74625', '76951'},
#  680: {'64051', '80613'},
#  681: {'60289', '90148'},
#  682: {'24958', '45207'},
#  683: {'68594', '70143', '70189'},
#  684: {'01579', '65037'},
#  685: {'47905', '97105'},
#  686: {'71963', '72819'},
#  687: {'62850', '64273', '93524', '95062'},
#  688: {'48376', '96804'},
#  689: {'02351', '38712'},
#  690: {'13458',
#   '16207',
#   '28657',
#   '41720',
#   '86540',
#   '87239',
#   '89206',
#   '92038',
#   '93820',
#   '98752'},
#  691: {'62891', '69304'},
#  692: {'09185', '50617'},
#  693: {'26315', '72514'},
#  694: {'23519', '45931'},
#  695: {'27041', '68309'},
#  696: {'59840', '61590', '95024'},
#  697: {'54290', '72816'},
#  698: {'92643', '96514'},
#  699: {'64097', '83964'},
#  700: {'27408', '84392'},
#  701: {'41972', '56870'},
#  702: {'04583',
#   '08961',
#   '46013',
#   '51928',
#   '71236',
#   '76953',
#   '78365',
#   '94086',
#   '94153'},
#  703: {'23578', '28957', '49527', '60839', '63850', '84097'},
#  704: {'53927', '68204'},
#  705: {'28134', '28970'},
#  706: {'26057', '76320'},
#  707: {'27058', '73026'},
#  708: {'72340', '76293'},
#  709: {'17348', '31690', '78925', '82609', '84592', '96354', '97810'},
#  710: {'50148', '60238'},
#  711: {'50239', '91358'},
#  712: {'16280', '57618'},
#  713: {'49387', '81532'},
#  714: {'14782', '79258', '87165'},
#  715: {'27685', '57394'},
#  716: {'71562', '74016'},
#  717: {'31786', '37901', '72486', '80513', '81054'},
#  718: {'09682', '60538'},
#  719: {'16089', '59714'},
#  720: {'03281', '39784', '72609', '87219', '95640'},
#  721: {'50871', '75081'},
#  722: {'78563', '87520'},
#  723: {'84721', '86139'},
#  724: {'09527', '58190'},
#  725: {'02789', '59672'},
#  726: {'04873', '83402'},
#  727: {'45739', '46312'},
#  728: {'59806', '98305'},
#  729: {'64325', '69528'},
#  730: {'90861', '91320'},
#  731: {'21453', '28567', '40539'},
#  732: {'03675', '27134'},
#  733: {'65349', '82406'},
#  734: {'01235', '74356'},
#  735: {'04859', '32150'},
#  736: {'54632', '69870'},
#  737: {'24067', '95861'},
#  738: {'06539', '37569'},
#  739: {'30721', '70935'},
#  740: {'13506', '45630'},
#  741: {'25386', '42736', '72451', '76148', '96150'},
#  742: {'75820', '96734'},
#  743: {'08452', '96342'},
#  744: {'01763', '58327'},
#  745: {'03984', '59342'},
#  746: {'13650', '42589'},
#  747: {'32957', '40632'},
#  748: {'02194', '14590', '59601'},
#  749: {'38549', '61742'},
#  750: {'80126', '97514'},
#  751: {'29158', '87412'},
#  752: {'09563', '76208', '80759', '91275', '94873'},
#  753: {'09486', '84527'},
#  754: {'23905', '64287'},
#  755: {'67892', '97508'},
#  756: {'38647', '78315'},
#  757: {'07956', '90251'},
#  758: {'41589', '92104'},
#  759: {'03981', '12907'},
#  760: {'08317', '14580', '96270'},
#  761: {'37419', '89105'},
#  762: {'34927', '43690', '79045', '82150', '94081'},
#  763: {'30849', '70415'},
#  764: {'30851', '38215'},
#  765: {'37984', '54819', '71950', '73962'},
#  957: {'19637', '20715'},
#  958: {'35287', '79031'},
#  959: {'97402', '98514'},
#  960: {'05846', '17508', '35096', '69423', '96104'},
#  961: {'05972', '30168'},
#  962: {'73105', '83045'},
#  963: {'34710', '59140'},
#  964: {'48153', '72654'},
#  965: {'75960', '96872'},
#  966: {'24586', '72956'},
#  967: {'46179', '91724'},
#  968: {'20381', '24876'},
#  969: {'54831', '78924', '98657'},
#  970: {'39867', '47605', '58917'},
#  971: {'05864', '37298', '42705'},
#  972: {'14892', '23047', '94380'},
#  973: {'26347', '74206'},
#  974: {'20438', '97824'},
#  975: {'46175', '76840'},
#  976: {'14852', '43109'},
#  977: {'10357', '79250'},
#  978: {'05726', '27503'},
#  979: {'74832', '76583'},
#  980: {'08162', '70352'},
#  981: {'25137', '81254'},
#  982: {'01975', '09513', '36729', '37024'},
#  983: {'52687', '64592'},
#  984: {'05231', '08653', '28504', '40728', '60185', '94732'},
#  985: {'53720', '78034'},
#  986: {'24538', '30567'},
#  987: {'17290', '59301'},
#  988: {'57084', '57621'},
#  989: {'20867', '30196'},
#  990: {'29470', '81576'},
#  991: {'53879', '73819'},
#  992: {'51890', '90827'},
#  993: {'09368', '38516', '38961', '87234'},
#  994: {'37190', '71492'},
#  995: {'37649', '83720'},
#  996: {'51706', '84297'},
#  997: {'15734', '85379'},
#  998: {'25497', '31927'},
#  999: {'06749', '69421'},
#  ...}

# %%
meme_idx_to_psuedo_img_idx = {}
for psuedo_img_idx, meme_idxs in psuedo_img_idx_to_meme_idxs.items():
    for meme_idx in meme_idxs:
        meme_idx_to_psuedo_img_idx[meme_idx] = psuedo_img_idx
print(len(meme_idx_to_psuedo_img_idx))

# for meme idxs that are not covered
non_covered_meme_idxs = set(df['id'].values) - set(meme_idx_to_psuedo_img_idx.keys())
for i, non_covered_meme_idx in enumerate(non_covered_meme_idxs, start=len(psuedo_img_idx_to_meme_idxs)):
    meme_idx_to_psuedo_img_idx[non_covered_meme_idx] = i
print(len(meme_idx_to_psuedo_img_idx))
# Out:
# 4289
# 10000

# %%
df['pseudo_img_idx'] = df['id'].map(meme_idx_to_psuedo_img_idx)

# %%
df.head()
# Out:
#           id            img  label  \
# 42953  42953  img/42953.png      0
# 23058  23058  img/23058.png      0
# 13894  13894  img/13894.png      0
# 37408  37408  img/37408.png      0
# 82403  82403  img/82403.png      0
#
#                                                     text  split  text_idx  \
# 42953   its their character not their color that matters  train         0
# 23058  don't be afraid to love again everyone is not ...  train         1
# 13894                           putting bows on your pet  train         2
# 37408  i love everything and everybody! except for sq...  train         3
# 82403  everybody loves chocolate chip cookies, even h...  train         4
#
#        pseudo_text_idx  pseudo_img_idx
# 42953             5484               0
# 23058             2036            1950
# 13894                0            4761
# 37408             3216            3126
# 82403             2244               1

# %%
df.nunique()
# Out:
# id                 10000
# img                10000
# label                  2
# text                8045
# split                  3
# text_idx            8045
# pseudo_text_idx     7499
# pseudo_img_idx      7352
# dtype: int64

# %%
file_path = f'{data_dir}/info.csv'
df.to_csv(file_path, index=False)
